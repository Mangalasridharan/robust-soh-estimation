# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('../Dataset/NCA Preprocessed/master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
# -------------------------
# 0. ONE-HOT encode temp & charge-rate
# -------------------------
df_one_hot = pd.get_dummies(df, columns=['temp','charge_rate'])

# -------------------------
# 1. Drop unused columns
# -------------------------
df_dropped = df_one_hot.drop(columns=['filename', 'cell_id', 'discharge_rate'])

# -------------------------
# 2. Identify columns
# -------------------------
ic_cols = [col for col in df_dropped.columns if 'IC' in col]      # 20 IC bins
cycle_col = 'cycle'
one_hot_cols = [col for col in df_dropped.columns 
                if 'temp_' in col or 'charge_rate_' in col]

# Convert to arrays
X_ic_all = df_dropped[ic_cols].values               # (N,20)
X_cycle_all = df_dropped[[cycle_col]].values        # (N,1)
X_onehot_all = df_dropped[one_hot_cols].values      # (N,6)
Y = df_dropped['SOH'].values                        # (N,)

# ---------------------------------------------------
# 3. Remove NaN / INF first
# ---------------------------------------------------
mask_clean = (
    ~np.isnan(X_ic_all).any(axis=1) &
    ~np.isnan(X_cycle_all).any(axis=1) &
    ~np.isnan(X_onehot_all).any(axis=1) &
    ~np.isnan(Y) &
    ~np.isinf(X_ic_all).any(axis=1) &
    ~np.isinf(X_cycle_all).any(axis=1) &
    ~np.isinf(X_onehot_all).any(axis=1) &
    ~np.isinf(Y)
)

print("Rows removed due to NaN/Inf:", np.sum(~mask_clean))

X_ic_all     = X_ic_all[mask_clean]
X_cycle_all  = X_cycle_all[mask_clean]
X_onehot_all = X_onehot_all[mask_clean]
Y            = Y[mask_clean]


# ---------------------------------------------------
# 4. REMOVE IC OUTLIERS (YOUR RULE: IC < 0 OR IC > 20)
# ---------------------------------------------------
LOW_LIMIT  = 0
HIGH_LIMIT = 20

mask_outlier = np.all(
    (X_ic_all >= LOW_LIMIT) & (X_ic_all <= HIGH_LIMIT),
    axis=1
)

print("Rows removed due to IC outliers:", np.sum(~mask_outlier))

# Apply mask everywhere
X_ic_all     = X_ic_all[mask_outlier]
X_cycle_all  = X_cycle_all[mask_outlier]
X_onehot_all = X_onehot_all[mask_outlier]
Y            = Y[mask_outlier]


# -------------------------
# 5. Train-test split
# -------------------------
X_ic_train, X_ic_test, \
X_cycle_train, X_cycle_test, \
X_onehot_train, X_onehot_test, \
y_train, y_test = train_test_split(
    X_ic_all, X_cycle_all, X_onehot_all, Y,
    train_size=0.8, random_state=42
)

# -------------------------
# 6. Standardize IC bins
# -------------------------
ic_scaler = StandardScaler()
X_ic_train = ic_scaler.fit_transform(X_ic_train)
X_ic_test = ic_scaler.transform(X_ic_test)

# -------------------------
# 7. Standardize cycle number
# -------------------------
cycle_scaler = StandardScaler()
X_cycle_train = cycle_scaler.fit_transform(X_cycle_train)
X_cycle_test = cycle_scaler.transform(X_cycle_test)

# -------------------------
# 8. Build context vector = cycle + one-hot
# -------------------------
X_context_train = np.concatenate([X_cycle_train, X_onehot_train], axis=1)
X_context_test = np.concatenate([X_cycle_test, X_onehot_test], axis=1)

# -------------------------
# 9. Normalize SOH target
# -------------------------
y_mean = y_train.mean()
y_std = y_train.std()

y_train = (y_train - y_mean) / y_std
y_test  = (y_test - y_mean) / y_std

# -------------------------
# 10. Expand dims for CNN/LSTM input
# -------------------------
X_ic_train = np.expand_dims(X_ic_train, axis=2)  
X_ic_test  = np.expand_dims(X_ic_test, axis=2)

# -------------------------
# 11. Print final shapes & ranges
# -------------------------
print("Final IC range:", X_ic_test.min(), X_ic_test.max())
print("IC:", X_ic_train.shape)
print("Context:", X_context_train.shape)
print("Y:", y_train.shape)
# Out:
# Rows removed due to NaN/Inf: 3
# Rows removed due to IC outliers: 4
# Final IC range: -8.413057359147434 11.611967272321516
# IC: (18109, 20, 1)
# Context: (18109, 7)
# Y: (18109,)

# %%
X_ic_train

# %%
plt.figure(figsize=(6,6))

for i in range(20):
    plt.boxplot(X_ic_train[i])
    plt.title(f"boxplot for ic bin{i+1}")
    plt.show()

# %%
print(len(X_ic_all))
# Out:
# 22637

# %%
ic_input = Input(shape=(X_ic_train.shape[1],X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=128, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = GRU(units=50, return_sequences=False)(x)

context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

combined = Concatenate()([x,c])

z = Dense(64, activation='relu')(combined)
z = Dropout(0.2)(z)
output = Dense(1, activation='linear')(z)

model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 128)    │     24,704 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 128)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 50)        │     27,000 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 82)        │          0 │ gru[0][0],        │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      5,312 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 57,593 (224.97 KB)
#  Trainable params: 57,593 (224.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_cnn_gru_1.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3425 - mae: 0.4225
# Epoch 1: val_loss improved from None to 0.03901, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.1671 - mae: 0.2721 - val_loss: 0.0390 - val_mae: 0.1110
# Epoch 2/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477 - mae: 0.1473
# Epoch 2: val_loss improved from 0.03901 to 0.02142, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0438 - mae: 0.1405 - val_loss: 0.0214 - val_mae: 0.0825
# Epoch 3/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0310 - mae: 0.1224
# Epoch 3: val_loss improved from 0.02142 to 0.01367, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0295 - mae: 0.1190 - val_loss: 0.0137 - val_mae: 0.0706
# Epoch 4/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246 - mae: 0.1081
# Epoch 4: val_loss improved from 0.01367 to 0.00947, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0221 - mae: 0.1046 - val_loss: 0.0095 - val_mae: 0.0586
# Epoch 5/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - mae: 0.1021
# Epoch 5: val_loss improved from 0.00947 to 0.00811, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0198 - mae: 0.1003 - val_loss: 0.0081 - val_mae: 0.0551
# Epoch 6/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - mae: 0.0973
# Epoch 6: val_loss improved from 0.00811 to 0.00796, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0182 - mae: 0.0968 - val_loss: 0.0080 - val_mae: 0.0546
# Epoch 7/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167 - mae: 0.0938
# Epoch 7: val_loss improved from 0.00796 to 0.00710, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0170 - mae: 0.0933 - val_loss: 0.0071 - val_mae: 0.0509
# Epoch 8/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - mae: 0.0923
# Epoch 8: val_loss did not improve from 0.00710
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0167 - mae: 0.0927 - val_loss: 0.0076 - val_mae: 0.0539
# Epoch 9/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - mae: 0.0922
# Epoch 9: val_loss did not improve from 0.00710
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0168 - mae: 0.0928 - val_loss: 0.0072 - val_mae: 0.0522
# Epoch 10/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160 - mae: 0.0911
# Epoch 10: val_loss did not improve from 0.00710
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0163 - mae: 0.0912 - val_loss: 0.0083 - val_mae: 0.0576
# Epoch 11/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0156 - mae: 0.0891
# Epoch 11: val_loss improved from 0.00710 to 0.00691, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0155 - mae: 0.0891 - val_loss: 0.0069 - val_mae: 0.0500
# Epoch 12/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - mae: 0.0898
# Epoch 12: val_loss did not improve from 0.00691
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0160 - mae: 0.0904 - val_loss: 0.0077 - val_mae: 0.0561
# Epoch 13/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158 - mae: 0.0888
# Epoch 13: val_loss improved from 0.00691 to 0.00638, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0152 - mae: 0.0881 - val_loss: 0.0064 - val_mae: 0.0468
# Epoch 14/100
# 440/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153 - mae: 0.0887
# Epoch 14: val_loss improved from 0.00638 to 0.00636, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0153 - mae: 0.0886 - val_loss: 0.0064 - val_mae: 0.0478
# Epoch 15/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - mae: 0.0874
# Epoch 15: val_loss did not improve from 0.00636
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0147 - mae: 0.0864 - val_loss: 0.0064 - val_mae: 0.0474
# Epoch 16/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - mae: 0.0880
# Epoch 16: val_loss did not improve from 0.00636
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0151 - mae: 0.0880 - val_loss: 0.0067 - val_mae: 0.0490
# Epoch 17/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0156 - mae: 0.0885
# Epoch 17: val_loss did not improve from 0.00636
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0152 - mae: 0.0877 - val_loss: 0.0065 - val_mae: 0.0460
# Epoch 18/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149 - mae: 0.0875
# Epoch 18: val_loss did not improve from 0.00636
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0149 - mae: 0.0868 - val_loss: 0.0070 - val_mae: 0.0506
# Epoch 19/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151 - mae: 0.0863
# Epoch 19: val_loss improved from 0.00636 to 0.00600, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0143 - mae: 0.0853 - val_loss: 0.0060 - val_mae: 0.0450
# Epoch 20/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - mae: 0.0854
# Epoch 20: val_loss did not improve from 0.00600
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0145 - mae: 0.0858 - val_loss: 0.0066 - val_mae: 0.0487
# Epoch 21/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0840
# Epoch 21: val_loss improved from 0.00600 to 0.00580, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0139 - mae: 0.0844 - val_loss: 0.0058 - val_mae: 0.0432
# Epoch 22/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mae: 0.0853
# Epoch 22: val_loss did not improve from 0.00580
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.0854 - val_loss: 0.0061 - val_mae: 0.0447
# Epoch 23/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - mae: 0.0858
# Epoch 23: val_loss did not improve from 0.00580
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0143 - mae: 0.0845 - val_loss: 0.0061 - val_mae: 0.0468
# Epoch 24/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - mae: 0.0838
# Epoch 24: val_loss improved from 0.00580 to 0.00566, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0146 - mae: 0.0858 - val_loss: 0.0057 - val_mae: 0.0436
# Epoch 25/100
# 440/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - mae: 0.0850
# Epoch 25: val_loss did not improve from 0.00566
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0135 - mae: 0.0831 - val_loss: 0.0060 - val_mae: 0.0456
# Epoch 26/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.0840
# Epoch 26: val_loss improved from 0.00566 to 0.00564, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0138 - mae: 0.0834 - val_loss: 0.0056 - val_mae: 0.0428
# Epoch 27/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - mae: 0.0828
# Epoch 27: val_loss did not improve from 0.00564
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0135 - mae: 0.0825 - val_loss: 0.0065 - val_mae: 0.0486
# Epoch 28/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0835
# Epoch 28: val_loss did not improve from 0.00564
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0139 - mae: 0.0837 - val_loss: 0.0063 - val_mae: 0.0489
# Epoch 29/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.0834
# Epoch 29: val_loss did not improve from 0.00564
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.0829 - val_loss: 0.0058 - val_mae: 0.0447
# Epoch 30/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0835
# Epoch 30: val_loss improved from 0.00564 to 0.00549, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0136 - mae: 0.0832 - val_loss: 0.0055 - val_mae: 0.0418
# Epoch 31/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - mae: 0.0828
# Epoch 31: val_loss did not improve from 0.00549
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0136 - mae: 0.0829 - val_loss: 0.0055 - val_mae: 0.0419
# Epoch 32/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0824
# Epoch 32: val_loss did not improve from 0.00549
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0134 - mae: 0.0823 - val_loss: 0.0058 - val_mae: 0.0445
# Epoch 33/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - mae: 0.0834
# Epoch 33: val_loss improved from 0.00549 to 0.00545, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0136 - mae: 0.0828 - val_loss: 0.0055 - val_mae: 0.0416
# Epoch 34/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0827
# Epoch 34: val_loss did not improve from 0.00545
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0135 - mae: 0.0825 - val_loss: 0.0055 - val_mae: 0.0412
# Epoch 35/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0839
# Epoch 35: val_loss did not improve from 0.00545
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0137 - mae: 0.0834 - val_loss: 0.0058 - val_mae: 0.0441
# Epoch 36/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - mae: 0.0816
# Epoch 36: val_loss did not improve from 0.00545
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0131 - mae: 0.0818 - val_loss: 0.0060 - val_mae: 0.0460
# Epoch 37/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0822
# Epoch 37: val_loss improved from 0.00545 to 0.00513, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0134 - mae: 0.0822 - val_loss: 0.0051 - val_mae: 0.0393
# Epoch 38/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0831
# Epoch 38: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0135 - mae: 0.0821 - val_loss: 0.0059 - val_mae: 0.0448
# Epoch 39/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0809
# Epoch 39: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0129 - mae: 0.0811 - val_loss: 0.0053 - val_mae: 0.0404
# Epoch 40/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0823
# Epoch 40: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0133 - mae: 0.0819 - val_loss: 0.0056 - val_mae: 0.0431
# Epoch 41/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0815
# Epoch 41: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0134 - mae: 0.0820 - val_loss: 0.0058 - val_mae: 0.0458
# Epoch 42/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0807
# Epoch 42: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0131 - mae: 0.0810 - val_loss: 0.0056 - val_mae: 0.0427
# Epoch 43/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0146 - mae: 0.0846
# Epoch 43: val_loss did not improve from 0.00513
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0137 - mae: 0.0829 - val_loss: 0.0053 - val_mae: 0.0404
# Epoch 44/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.0811
# Epoch 44: val_loss improved from 0.00513 to 0.00502, saving model to best_cnn_gru_1.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0130 - mae: 0.0811 - val_loss: 0.0050 - val_mae: 0.0389
# Epoch 45/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mae: 0.0800
# Epoch 45: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0127 - mae: 0.0798 - val_loss: 0.0058 - val_mae: 0.0449
# Epoch 46/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mae: 0.0816
# Epoch 46: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0130 - mae: 0.0810 - val_loss: 0.0050 - val_mae: 0.0392
# Epoch 47/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - mae: 0.0802
# Epoch 47: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0130 - mae: 0.0807 - val_loss: 0.0058 - val_mae: 0.0459
# Epoch 48/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mae: 0.0788
# Epoch 48: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0127 - mae: 0.0801 - val_loss: 0.0051 - val_mae: 0.0391
# Epoch 49/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0809
# Epoch 49: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0128 - mae: 0.0808 - val_loss: 0.0054 - val_mae: 0.0418
# Epoch 50/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mae: 0.0794
# Epoch 50: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0130 - mae: 0.0802 - val_loss: 0.0053 - val_mae: 0.0409
# Epoch 51/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0806
# Epoch 51: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0130 - mae: 0.0802 - val_loss: 0.0054 - val_mae: 0.0415
# Epoch 52/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mae: 0.0794
# Epoch 52: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0129 - mae: 0.0798 - val_loss: 0.0051 - val_mae: 0.0400
# Epoch 53/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0807
# Epoch 53: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0128 - mae: 0.0803 - val_loss: 0.0050 - val_mae: 0.0383
# Epoch 54/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0805
# Epoch 54: val_loss did not improve from 0.00502
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0129 - mae: 0.0807 - val_loss: 0.0052 - val_mae: 0.0413

# %%
test_loss, test_mae = model.evaluate([X_ic_test, X_context_test], y_test, verbose=1)
print(f"Test MAE (normalized): {test_mae:.4f}")
print(f"Test MSE (normalized): {test_loss:.4f}")

# Inverse transform MAE to original units
test_mae_real = test_mae * y_std
print(f"Test MAE (original SOH units): {test_mae_real:.4f}")

# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE over Epochs')

plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mae: 0.0383
# Test MAE (normalized): 0.0383
# Test MSE (normalized): 0.0032
# Test MAE (original SOH units): 0.2547

# %%
import matplotlib.pyplot as plt

y_pred = model.predict([X_ic_test, X_context_test]).flatten()

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+GRU SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
r2 = r2_score(y_test, y_pred)

print(f"R-squared (normalized): {r2:.4f}")

y_test_real = y_test * y_std + y_mean
y_pred_real = y_pred * y_std + y_mean

r2_real = r2_score(y_test_real, y_pred_real)
print(f"R-squared (original SOH units): {r2_real:.4f}")
# Out:
# R-squared (normalized): 0.9968
# R-squared (original SOH units): 0.9968

# %%
X_ic_test_25 = []
X_context_test_25 = []
X_ic_test_35 = []
X_context_test_35 = []
X_ic_test_45 = []
X_context_test_45 = []
y_test_25 = []
y_test_35 = []  
y_test_45 = []

for i in range(X_context_test.shape[0]):
    if X_context_test[i, 1] > 0:      # temp_25 one-hot
        X_ic_test_25.append(X_ic_test[i])
        X_context_test_25.append(X_context_test[i])
        y_test_25.append(y_test[i])
    if X_context_test[i, 2] > 0:      # temp_35 one-hot
        X_ic_test_35.append(X_ic_test[i])
        X_context_test_35.append(X_context_test[i])
        y_test_35.append(y_test[i])
    if X_context_test[i, 3] > 0:      # temp_45 one-hot
        X_ic_test_45.append(X_ic_test[i])
        X_context_test_45.append(X_context_test[i])
        y_test_45.append(y_test[i])

X_ic_test_25 = np.array(X_ic_test_25)
X_ic_test_35 = np.array(X_ic_test_35)
X_ic_test_45 = np.array(X_ic_test_45)

X_context_test_25 = np.array(X_context_test_25)
X_context_test_35 = np.array(X_context_test_35)
X_context_test_45 = np.array(X_context_test_45)

y_test_25 = np.array(y_test_25)
y_test_35 = np.array(y_test_35)
y_test_45 = np.array(y_test_45)

print(X_ic_test_25.shape)
print(X_ic_test_35.shape)
print(X_ic_test_45.shape)

print(X_context_test_25.shape)
print(X_context_test_35.shape)
print(X_context_test_45.shape)


print(y_test_25.shape)
print(y_test_35.shape)
print(y_test_45.shape)
# Out:
# (1162, 20, 1)
# (235, 20, 1)
# (3131, 20, 1)
# (1162, 7)
# (235, 7)
# (3131, 7)
# (1162,)
# (235,)
# (3131,)

# %%
X_ic_test_25_seq = np.expand_dims(X_ic_test_25, axis=2)
X_ic_test_35_seq = np.expand_dims(X_ic_test_35, axis=2)
X_ic_test_45_seq = np.expand_dims(X_ic_test_45, axis=2)
print(X_ic_test_25_seq.shape)
print(X_ic_test_35_seq.shape)
print(X_ic_test_45_seq.shape)
# Out:
# (1162, 20, 1, 1)
# (235, 20, 1, 1)
# (3131, 20, 1, 1)

# %%
cnn_gru = keras.models.load_model(r'best_cnn_gru_1.keras')

# %%
y_pred_25_scaled = cnn_gru.predict([X_ic_test_25_seq, X_context_test_25]).flatten()
y_pred_35_scaled = cnn_gru.predict([X_ic_test_35_seq, X_context_test_35]).flatten()
y_pred_45_scaled = cnn_gru.predict([X_ic_test_45_seq, X_context_test_45]).flatten()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred_25 = y_pred_25_scaled * y_std + y_mean
y_pred_35 = y_pred_35_scaled * y_std + y_mean
y_pred_45 = y_pred_45_scaled * y_std + y_mean

y_true_25 = y_test_25 * y_std + y_mean
y_true_35 = y_test_35 * y_std + y_mean
y_true_45 = y_test_45 * y_std + y_mean

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def metrics(y_t, y_p):
    return (mean_absolute_error(y_t, y_p),
            mean_squared_error(y_t, y_p),
            r2_score(y_t, y_p))

mae_25, mse_25, r2_25 = metrics(y_true_25, y_pred_25)
print("25C → MAE:", mae_25, "MSE:", mse_25, "R²:", r2_25)


mae_35, mse_35, r2_35 = metrics(y_true_35, y_pred_35)
print("35C → MAE:", mae_35, "MSE:", mse_35, "R²:", r2_35)

mae_45, mse_45, r2_45 = metrics(y_true_45, y_pred_45)
print("45C → MAE:", mae_45, "MSE:", mse_45, "R²:", r2_45)
# Out:
# 25C → MAE: 0.3847903125793392 MSE: 0.26601168675942877 R²: 0.9924487813462113
# 35C → MAE: 0.1535104244092494 MSE: 0.05442196727916806 R²: 0.9982940796277329
# 45C → MAE: 0.21396891111278915 MSE: 0.09991693190763101 R²: 0.9974599438481219

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scatter(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=0.6, s=15)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    plt.title(title, fontsize=14)
    plt.xlabel("True SOH", fontsize=12)
    plt.ylabel("Predicted SOH", fontsize=12)
    plt.grid(True)

# %%
plt.figure(figsize=(22,6))

plt.subplot(1,3,1)
plot_scatter(y_true_25, y_pred_25, "SOH Prediction @ 25°C")

plt.subplot(1,3,2)
plot_scatter(y_true_35, y_pred_35, "SOH Prediction @ 35°C")

plt.subplot(1,3,3)
plot_scatter(y_true_45, y_pred_45, "SOH Prediction @ 45°C")

plt.show()
