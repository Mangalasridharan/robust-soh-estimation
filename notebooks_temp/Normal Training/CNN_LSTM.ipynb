# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r'../Dataset/NCA Preprocessed/master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
df_one_hot = pd.get_dummies(df, columns=['temp','charge_rate'])
df_one_hot
# Out:
#                 filename  cell_id  discharge_rate  cycle     SOH  IC_bin_1  \
# 0      CY25-025_1-#1.csv        1             1.0      1   99.96  3.206253
# 1      CY25-025_1-#1.csv        1             1.0      2   99.98  3.185611
# 2      CY25-025_1-#1.csv        1             1.0      3  100.00  3.166235
# 3      CY25-025_1-#1.csv        1             1.0      4   99.97  3.139468
# 4      CY25-025_1-#1.csv        1             1.0      5   99.93  3.132129
# ...                  ...      ...             ...    ...     ...       ...
# 22639   CY45-05_1-#9.csv        9             1.0    411   84.65  2.514883
# 22640   CY45-05_1-#9.csv        9             1.0    412   84.61  2.510205
# 22641   CY45-05_1-#9.csv        9             1.0    413   84.60  2.513525
# 22642   CY45-05_1-#9.csv        9             1.0    414   84.58  2.508238
# 22643   CY45-05_1-#9.csv        9             1.0    415   84.55  2.509477
#
#        IC_bin_2  IC_bin_3  IC_bin_4  IC_bin_5  ...  IC_bin_17  IC_bin_18  \
# 0      3.435524  3.772510  4.192327  4.376286  ...   4.058616   3.920543
# 1      3.409977  3.737496  4.066281  4.266975  ...   4.055173   3.905594
# 2      3.397673  3.713245  4.049932  4.278990  ...   4.015124   3.896722
# 3      3.376350  3.683448  4.050734  4.300114  ...   4.023064   3.867330
# 4      3.346752  3.653736  4.027798  4.299433  ...   4.008745   3.881142
# ...         ...       ...       ...       ...  ...        ...        ...
# 22639  2.565545  2.627766  2.699047  2.773160  ...   3.564230   3.413748
# 22640  2.560754  2.625429  2.698454  2.772929  ...   3.559024   3.417873
# 22641  2.562124  2.623266  2.694897  2.769636  ...   3.562536   3.425323
# 22642  2.557557  2.619624  2.690607  2.765388  ...   3.569719   3.425509
# 22643  2.557809  2.618544  2.690226  2.766575  ...   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20  temp_25  temp_35  temp_45  charge_rate_0.25  \
# 0       3.792856   3.647914     True    False    False              True
# 1       3.737473   3.648392     True    False    False              True
# 2       3.756668   3.646670     True    False    False              True
# 3       3.752034   3.631178     True    False    False              True
# 4       3.761407   3.626212     True    False    False              True
# ...          ...        ...      ...      ...      ...               ...
# 22639   3.287599   3.193869    False    False     True             False
# 22640   3.299083   3.207045    False    False     True             False
# 22641   3.303745   3.206924    False    False     True             False
# 22642   3.299934   3.202914    False    False     True             False
# 22643   3.298753   3.200880    False    False     True             False
#
#        charge_rate_0.5  charge_rate_1.0
# 0                False            False
# 1                False            False
# 2                False            False
# 3                False            False
# 4                False            False
# ...                ...              ...
# 22639             True            False
# 22640             True            False
# 22641             True            False
# 22642             True            False
# 22643             True            False
#
# [22644 rows x 31 columns]

# %%
# -------------------------
# 0. ONE-HOT encode temp & charge-rate
# -------------------------
df_one_hot = pd.get_dummies(df, columns=['temp','charge_rate'])

# -------------------------
# 1. Drop unused columns
# -------------------------
df_dropped = df_one_hot.drop(columns=['filename', 'cell_id', 'discharge_rate'])

# -------------------------
# 2. Identify columns
# -------------------------
ic_cols = [col for col in df_dropped.columns if 'IC' in col]      # 20 IC bins
cycle_col = 'cycle'
one_hot_cols = [col for col in df_dropped.columns 
                if 'temp_' in col or 'charge_rate_' in col]

# Convert to arrays
X_ic_all = df_dropped[ic_cols].values               # (N,20)
X_cycle_all = df_dropped[[cycle_col]].values        # (N,1)
X_onehot_all = df_dropped[one_hot_cols].values      # (N,6)
Y = df_dropped['SOH'].values                        # (N,)

# ---------------------------------------------------
# 3. Remove NaN / INF first
# ---------------------------------------------------
mask_clean = (
    ~np.isnan(X_ic_all).any(axis=1) &
    ~np.isnan(X_cycle_all).any(axis=1) &
    ~np.isnan(X_onehot_all).any(axis=1) &
    ~np.isnan(Y) &
    ~np.isinf(X_ic_all).any(axis=1) &
    ~np.isinf(X_cycle_all).any(axis=1) &
    ~np.isinf(X_onehot_all).any(axis=1) &
    ~np.isinf(Y)
)

print("Rows removed due to NaN/Inf:", np.sum(~mask_clean))

X_ic_all     = X_ic_all[mask_clean]
X_cycle_all  = X_cycle_all[mask_clean]
X_onehot_all = X_onehot_all[mask_clean]
Y            = Y[mask_clean]


# ---------------------------------------------------
# 4. REMOVE IC OUTLIERS (YOUR RULE: IC < 0 OR IC > 20)
# ---------------------------------------------------
LOW_LIMIT  = 0
HIGH_LIMIT = 20

mask_outlier = np.all(
    (X_ic_all >= LOW_LIMIT) & (X_ic_all <= HIGH_LIMIT),
    axis=1
)

print("Rows removed due to IC outliers:", np.sum(~mask_outlier))

# Apply mask everywhere
X_ic_all     = X_ic_all[mask_outlier]
X_cycle_all  = X_cycle_all[mask_outlier]
X_onehot_all = X_onehot_all[mask_outlier]
Y            = Y[mask_outlier]


# -------------------------
# 5. Train-test split
# -------------------------
X_ic_train, X_ic_test, \
X_cycle_train, X_cycle_test, \
X_onehot_train, X_onehot_test, \
y_train, y_test = train_test_split(
    X_ic_all, X_cycle_all, X_onehot_all, Y,
    train_size=0.8, random_state=42
)

# -------------------------
# 6. Standardize IC bins
# -------------------------
ic_scaler = StandardScaler()
X_ic_train = ic_scaler.fit_transform(X_ic_train)
X_ic_test = ic_scaler.transform(X_ic_test)

# -------------------------
# 7. Standardize cycle number
# -------------------------
cycle_scaler = StandardScaler()
X_cycle_train = cycle_scaler.fit_transform(X_cycle_train)
X_cycle_test = cycle_scaler.transform(X_cycle_test)

# -------------------------
# 8. Build context vector = cycle + one-hot
# -------------------------
X_context_train = np.concatenate([X_cycle_train, X_onehot_train], axis=1)
X_context_test = np.concatenate([X_cycle_test, X_onehot_test], axis=1)

# -------------------------
# 9. Normalize SOH target
# -------------------------
y_mean = y_train.mean()
y_std = y_train.std()

y_train = (y_train - y_mean) / y_std
y_test  = (y_test - y_mean) / y_std

# -------------------------
# 10. Expand dims for CNN/LSTM input
# -------------------------
X_ic_train = np.expand_dims(X_ic_train, axis=2)  
X_ic_test  = np.expand_dims(X_ic_test, axis=2)

# -------------------------
# 11. Print final shapes & ranges
# -------------------------
print("Final IC range:", X_ic_test.min(), X_ic_test.max())
print("IC:", X_ic_train.shape)
print("Context:", X_context_train.shape)
print("Y:", y_train.shape)
# Out:
# Rows removed due to NaN/Inf: 3
# Rows removed due to IC outliers: 4
# Final IC range: -8.413057359147434 11.611967272321516
# IC: (18109, 20, 1)
# Context: (18109, 7)
# Y: (18109,)

# %%
# -------------------------
# IC Input (20 timesteps, 1 channel)
# -------------------------
ic_input = Input(shape=(X_ic_train.shape[1], X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=64, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = LSTM(64)(x)

# -------------------------
# Context Input (cycle_scaled + temp one-hot + charge one-hot)
# -------------------------
context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

# -------------------------
# Combine IC latent + Context latent
# -------------------------
combined = Concatenate()([x, c])

# -------------------------
# Final dense layers
# -------------------------
z = Dense(64, activation='relu')(combined)
z = Dropout(0.3)(z)
output = Dense(1, activation='linear')(z)

# -------------------------
# Build model
# -------------------------
model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 64)     │     12,352 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 64)     │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     33,024 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 96)        │          0 │ lstm[0][0],       │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      6,208 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 52,161 (203.75 KB)
#  Trainable params: 52,161 (203.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_cnn_lstm.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4548 - mae: 0.4905
# Epoch 1: val_loss improved from None to 0.04496, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - loss: 0.2249 - mae: 0.3173 - val_loss: 0.0450 - val_mae: 0.1252
# Epoch 2/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0666 - mae: 0.1827
# Epoch 2: val_loss improved from 0.04496 to 0.02503, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0613 - mae: 0.1735 - val_loss: 0.0250 - val_mae: 0.0915
# Epoch 3/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0457 - mae: 0.1513
# Epoch 3: val_loss improved from 0.02503 to 0.02070, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 0.0435 - mae: 0.1479 - val_loss: 0.0207 - val_mae: 0.0902
# Epoch 4/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0372 - mae: 0.1391
# Epoch 4: val_loss improved from 0.02070 to 0.01227, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0352 - mae: 0.1358 - val_loss: 0.0123 - val_mae: 0.0681
# Epoch 5/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0305 - mae: 0.1277
# Epoch 5: val_loss improved from 0.01227 to 0.01063, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0307 - mae: 0.1267 - val_loss: 0.0106 - val_mae: 0.0670
# Epoch 6/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0301 - mae: 0.1256
# Epoch 6: val_loss improved from 0.01063 to 0.00855, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0298 - mae: 0.1237 - val_loss: 0.0085 - val_mae: 0.0589
# Epoch 7/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0273 - mae: 0.1179
# Epoch 7: val_loss improved from 0.00855 to 0.00792, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0274 - mae: 0.1191 - val_loss: 0.0079 - val_mae: 0.0553
# Epoch 8/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0259 - mae: 0.1165
# Epoch 8: val_loss improved from 0.00792 to 0.00759, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0260 - mae: 0.1160 - val_loss: 0.0076 - val_mae: 0.0542
# Epoch 9/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0265 - mae: 0.1170
# Epoch 9: val_loss improved from 0.00759 to 0.00750, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0258 - mae: 0.1144 - val_loss: 0.0075 - val_mae: 0.0538
# Epoch 10/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0268 - mae: 0.1145
# Epoch 10: val_loss improved from 0.00750 to 0.00731, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0251 - mae: 0.1132 - val_loss: 0.0073 - val_mae: 0.0527
# Epoch 11/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0252 - mae: 0.1125
# Epoch 11: val_loss did not improve from 0.00731
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0246 - mae: 0.1124 - val_loss: 0.0082 - val_mae: 0.0582
# Epoch 12/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0230 - mae: 0.1094
# Epoch 12: val_loss did not improve from 0.00731
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0238 - mae: 0.1102 - val_loss: 0.0080 - val_mae: 0.0579
# Epoch 13/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0241 - mae: 0.1107
# Epoch 13: val_loss improved from 0.00731 to 0.00696, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0240 - mae: 0.1105 - val_loss: 0.0070 - val_mae: 0.0524
# Epoch 14/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0231 - mae: 0.1082
# Epoch 14: val_loss did not improve from 0.00696
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0238 - mae: 0.1094 - val_loss: 0.0079 - val_mae: 0.0580
# Epoch 15/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0240 - mae: 0.1092
# Epoch 15: val_loss improved from 0.00696 to 0.00654, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0233 - mae: 0.1089 - val_loss: 0.0065 - val_mae: 0.0486
# Epoch 16/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0238 - mae: 0.1094
# Epoch 16: val_loss did not improve from 0.00654
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0231 - mae: 0.1085 - val_loss: 0.0068 - val_mae: 0.0513
# Epoch 17/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - mae: 0.1069
# Epoch 17: val_loss did not improve from 0.00654
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0231 - mae: 0.1074 - val_loss: 0.0083 - val_mae: 0.0613
# Epoch 18/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0231 - mae: 0.1055
# Epoch 18: val_loss did not improve from 0.00654
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 0.0224 - mae: 0.1068 - val_loss: 0.0069 - val_mae: 0.0527
# Epoch 19/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0238 - mae: 0.1084
# Epoch 19: val_loss did not improve from 0.00654
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0225 - mae: 0.1063 - val_loss: 0.0077 - val_mae: 0.0579
# Epoch 20/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0228 - mae: 0.1069
# Epoch 20: val_loss did not improve from 0.00654
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0225 - mae: 0.1064 - val_loss: 0.0074 - val_mae: 0.0563
# Epoch 21/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0233 - mae: 0.1082
# Epoch 21: val_loss improved from 0.00654 to 0.00622, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0230 - mae: 0.1077 - val_loss: 0.0062 - val_mae: 0.0480
# Epoch 22/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0229 - mae: 0.1068
# Epoch 22: val_loss did not improve from 0.00622
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0229 - mae: 0.1070 - val_loss: 0.0065 - val_mae: 0.0495
# Epoch 23/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0219 - mae: 0.1050
# Epoch 23: val_loss did not improve from 0.00622
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0222 - mae: 0.1052 - val_loss: 0.0093 - val_mae: 0.0638
# Epoch 24/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - mae: 0.1056
# Epoch 24: val_loss improved from 0.00622 to 0.00596, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0225 - mae: 0.1065 - val_loss: 0.0060 - val_mae: 0.0460
# Epoch 25/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0216 - mae: 0.1043
# Epoch 25: val_loss improved from 0.00596 to 0.00589, saving model to best_cnn_lstm.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0222 - mae: 0.1050 - val_loss: 0.0059 - val_mae: 0.0453
# Epoch 26/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0226 - mae: 0.1068
# Epoch 26: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0222 - mae: 0.1052 - val_loss: 0.0061 - val_mae: 0.0460
# Epoch 27/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0227 - mae: 0.1064
# Epoch 27: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0219 - mae: 0.1045 - val_loss: 0.0067 - val_mae: 0.0517
# Epoch 28/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0216 - mae: 0.1044
# Epoch 28: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0217 - mae: 0.1043 - val_loss: 0.0060 - val_mae: 0.0470
# Epoch 29/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0223 - mae: 0.1061
# Epoch 29: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0220 - mae: 0.1047 - val_loss: 0.0075 - val_mae: 0.0575
# Epoch 30/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0217 - mae: 0.1047
# Epoch 30: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0221 - mae: 0.1052 - val_loss: 0.0061 - val_mae: 0.0474
# Epoch 31/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0214 - mae: 0.1036
# Epoch 31: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0217 - mae: 0.1037 - val_loss: 0.0063 - val_mae: 0.0496
# Epoch 32/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0220 - mae: 0.1044
# Epoch 32: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0219 - mae: 0.1043 - val_loss: 0.0060 - val_mae: 0.0473
# Epoch 33/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0231 - mae: 0.1036
# Epoch 33: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0215 - mae: 0.1033 - val_loss: 0.0066 - val_mae: 0.0503
# Epoch 34/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0217 - mae: 0.1043
# Epoch 34: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0220 - mae: 0.1047 - val_loss: 0.0066 - val_mae: 0.0480
# Epoch 35/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0222 - mae: 0.1026
# Epoch 35: val_loss did not improve from 0.00589
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0216 - mae: 0.1032 - val_loss: 0.0065 - val_mae: 0.0498

# %%
test_loss, test_mae = model.evaluate([X_ic_test, X_context_test], y_test, verbose=1)
print(f"Test MAE (normalized): {test_mae:.4f}")
print(f"Test MSE (normalized): {test_loss:.4f}")

# Inverse transform MAE to original units
test_mae_real = test_mae * y_std
print(f"Test MAE (original SOH units): {test_mae_real:.4f}")

# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE over Epochs')

plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0043 - mae: 0.0451
# Test MAE (normalized): 0.0451
# Test MSE (normalized): 0.0043
# Test MAE (original SOH units): 0.2999

# %%
import matplotlib.pyplot as plt

y_pred = model.predict([X_ic_test, X_context_test]).flatten()

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+LSTM SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step

# %%
r2 = r2_score(y_test, y_pred)

print(f"R-squared (normalized): {r2:.4f}")

y_test_real = y_test * y_std + y_mean
y_pred_real = y_pred * y_std + y_mean

r2_real = r2_score(y_test_real, y_pred_real)
print(f"R-squared (original SOH units): {r2_real:.4f}")
# Out:
# R-squared (normalized): 0.9957
# R-squared (original SOH units): 0.9957

# %%
X_ic_test_25 = []
X_context_test_25 = []
X_ic_test_35 = []
X_context_test_35 = []
X_ic_test_45 = []
X_context_test_45 = []
y_test_25 = []
y_test_35 = []  
y_test_45 = []

for i in range(X_context_test.shape[0]):
    if X_context_test[i, 1] > 0:      # temp_25 one-hot
        X_ic_test_25.append(X_ic_test[i])
        X_context_test_25.append(X_context_test[i])
        y_test_25.append(y_test[i])
    if X_context_test[i, 2] > 0:      # temp_35 one-hot
        X_ic_test_35.append(X_ic_test[i])
        X_context_test_35.append(X_context_test[i])
        y_test_35.append(y_test[i])
    if X_context_test[i, 3] > 0:      # temp_45 one-hot
        X_ic_test_45.append(X_ic_test[i])
        X_context_test_45.append(X_context_test[i])
        y_test_45.append(y_test[i])

X_ic_test_25 = np.array(X_ic_test_25)
X_ic_test_35 = np.array(X_ic_test_35)
X_ic_test_45 = np.array(X_ic_test_45)

X_context_test_25 = np.array(X_context_test_25)
X_context_test_35 = np.array(X_context_test_35)
X_context_test_45 = np.array(X_context_test_45)

y_test_25 = np.array(y_test_25)
y_test_35 = np.array(y_test_35)
y_test_45 = np.array(y_test_45)

print(X_ic_test_25.shape)
print(X_ic_test_35.shape)
print(X_ic_test_45.shape)

print(X_context_test_25.shape)
print(X_context_test_35.shape)
print(X_context_test_45.shape)


print(y_test_25.shape)
print(y_test_35.shape)
print(y_test_45.shape)
# Out:
# (1162, 20, 1)
# (235, 20, 1)
# (3131, 20, 1)
# (1162, 7)
# (235, 7)
# (3131, 7)
# (1162,)
# (235,)
# (3131,)

# %%
X_ic_test_25_seq = np.expand_dims(X_ic_test_25, axis=2)
X_ic_test_35_seq = np.expand_dims(X_ic_test_35, axis=2)
X_ic_test_45_seq = np.expand_dims(X_ic_test_45, axis=2)
print(X_ic_test_25_seq.shape)
print(X_ic_test_35_seq.shape)
print(X_ic_test_45_seq.shape)
# Out:
# (1162, 20, 1, 1)
# (235, 20, 1, 1)
# (3131, 20, 1, 1)

# %%
cnn_lstm = keras.models.load_model(r'best_cnn_lstm.keras')

# %%
y_pred_25_scaled = cnn_lstm.predict([X_ic_test_25_seq, X_context_test_25]).flatten()
y_pred_35_scaled = cnn_lstm.predict([X_ic_test_35_seq, X_context_test_35]).flatten()
y_pred_45_scaled = cnn_lstm.predict([X_ic_test_45_seq, X_context_test_45]).flatten()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred_25 = y_pred_25_scaled * y_std + y_mean
y_pred_35 = y_pred_35_scaled * y_std + y_mean
y_pred_45 = y_pred_45_scaled * y_std + y_mean

y_true_25 = y_test_25 * y_std + y_mean
y_true_35 = y_test_35 * y_std + y_mean
y_true_45 = y_test_45 * y_std + y_mean

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def metrics(y_t, y_p):
    return (mean_absolute_error(y_t, y_p),
            mean_squared_error(y_t, y_p),
            r2_score(y_t, y_p))

mae_25, mse_25, r2_25 = metrics(y_true_25, y_pred_25)
print("25C → MAE:", mae_25, "MSE:", mse_25, "R²:", r2_25)


mae_35, mse_35, r2_35 = metrics(y_true_35, y_pred_35)
print("35C → MAE:", mae_35, "MSE:", mse_35, "R²:", r2_35)

mae_45, mse_45, r2_45 = metrics(y_true_45, y_pred_45)
print("45C → MAE:", mae_45, "MSE:", mse_45, "R²:", r2_45)
# Out:
# 25C → MAE: 0.4470751119529924 MSE: 0.3739718668844926 R²: 0.9893841380744891
# 35C → MAE: 0.15498760584929638 MSE: 0.04683724657484937 R²: 0.9985318315910363
# 45C → MAE: 0.25617090345519256 MSE: 0.13396766849207611 R²: 0.996594316959005

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scatter(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=0.6, s=15)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    plt.title(title, fontsize=14)
    plt.xlabel("True SOH", fontsize=12)
    plt.ylabel("Predicted SOH", fontsize=12)
    plt.grid(True)

# %%
plt.figure(figsize=(22,6))

plt.subplot(1,3,1)
plot_scatter(y_true_25, y_pred_25, "SOH Prediction @ 25°C")

plt.subplot(1,3,2)
plot_scatter(y_true_35, y_pred_35, "SOH Prediction @ 35°C")

plt.subplot(1,3,3)
plot_scatter(y_true_45, y_pred_45, "SOH Prediction @ 45°C")

plt.show()
