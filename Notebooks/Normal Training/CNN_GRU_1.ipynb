# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r'F:\College\SEM 8\Project Phase 2\Dataset\NCA Preprocessed\master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
# -------------------------
# 0. ONE-HOT encode temp & charge-rate
# -------------------------
df_one_hot = pd.get_dummies(df, columns=['temp','charge_rate'])

# -------------------------
# 1. Drop unused columns
# -------------------------
df_dropped = df_one_hot.drop(columns=['filename', 'cell_id', 'discharge_rate'])

# -------------------------
# 2. Identify columns
# -------------------------
ic_cols = [col for col in df_dropped.columns if 'IC' in col]      # 20 IC bins
cycle_col = 'cycle'
one_hot_cols = [col for col in df_dropped.columns 
                if 'temp_' in col or 'charge_rate_' in col]

# Convert to arrays
X_ic_all = df_dropped[ic_cols].values               # (N,20)
X_cycle_all = df_dropped[[cycle_col]].values        # (N,1)
X_onehot_all = df_dropped[one_hot_cols].values      # (N,6)
Y = df_dropped['SOH'].values                        # (N,)

# ---------------------------------------------------
# 3. Remove NaN / INF first
# ---------------------------------------------------
mask_clean = (
    ~np.isnan(X_ic_all).any(axis=1) &
    ~np.isnan(X_cycle_all).any(axis=1) &
    ~np.isnan(X_onehot_all).any(axis=1) &
    ~np.isnan(Y) &
    ~np.isinf(X_ic_all).any(axis=1) &
    ~np.isinf(X_cycle_all).any(axis=1) &
    ~np.isinf(X_onehot_all).any(axis=1) &
    ~np.isinf(Y)
)

print("Rows removed due to NaN/Inf:", np.sum(~mask_clean))

X_ic_all     = X_ic_all[mask_clean]
X_cycle_all  = X_cycle_all[mask_clean]
X_onehot_all = X_onehot_all[mask_clean]
Y            = Y[mask_clean]


# ---------------------------------------------------
# 4. REMOVE IC OUTLIERS (YOUR RULE: IC < 0 OR IC > 20)
# ---------------------------------------------------
LOW_LIMIT  = 0
HIGH_LIMIT = 20

mask_outlier = np.all(
    (X_ic_all >= LOW_LIMIT) & (X_ic_all <= HIGH_LIMIT),
    axis=1
)

print("Rows removed due to IC outliers:", np.sum(~mask_outlier))

# Apply mask everywhere
X_ic_all     = X_ic_all[mask_outlier]
X_cycle_all  = X_cycle_all[mask_outlier]
X_onehot_all = X_onehot_all[mask_outlier]
Y            = Y[mask_outlier]


# -------------------------
# 5. Train-test split
# -------------------------
X_ic_train, X_ic_test, \
X_cycle_train, X_cycle_test, \
X_onehot_train, X_onehot_test, \
y_train, y_test = train_test_split(
    X_ic_all, X_cycle_all, X_onehot_all, Y,
    train_size=0.8, random_state=42
)

# -------------------------
# 6. Standardize IC bins
# -------------------------
ic_scaler = StandardScaler()
X_ic_train = ic_scaler.fit_transform(X_ic_train)
X_ic_test = ic_scaler.transform(X_ic_test)

# -------------------------
# 7. Standardize cycle number
# -------------------------
cycle_scaler = StandardScaler()
X_cycle_train = cycle_scaler.fit_transform(X_cycle_train)
X_cycle_test = cycle_scaler.transform(X_cycle_test)

# -------------------------
# 8. Build context vector = cycle + one-hot
# -------------------------
X_context_train = np.concatenate([X_cycle_train, X_onehot_train], axis=1)
X_context_test = np.concatenate([X_cycle_test, X_onehot_test], axis=1)

# -------------------------
# 9. Normalize SOH target
# -------------------------
y_mean = y_train.mean()
y_std = y_train.std()

y_train = (y_train - y_mean) / y_std
y_test  = (y_test - y_mean) / y_std

# -------------------------
# 10. Expand dims for CNN/LSTM input
# -------------------------
X_ic_train = np.expand_dims(X_ic_train, axis=2)  
X_ic_test  = np.expand_dims(X_ic_test, axis=2)

# -------------------------
# 11. Print final shapes & ranges
# -------------------------
print("Final IC range:", X_ic_test.min(), X_ic_test.max())
print("IC:", X_ic_train.shape)
print("Context:", X_context_train.shape)
print("Y:", y_train.shape)
# Out:
# Rows removed due to NaN/Inf: 3
# Rows removed due to IC outliers: 4
# Final IC range: -8.413057359147434 11.611967272321516
# IC: (18109, 20, 1)
# Context: (18109, 7)
# Y: (18109,)

# %%
ic_input = Input(shape=(X_ic_train.shape[1],X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=128, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = GRU(units=50, return_sequences=False)(x)

context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

combined = Concatenate()([x,c])

z = Dense(64, activation='relu')(combined)
z = Dropout(0.2)(z)
output = Dense(1, activation='linear')(z)

model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 128)    │     24,704 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 128)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 50)        │     27,000 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 82)        │          0 │ gru[0][0],        │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      5,312 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 57,593 (224.97 KB)
#  Trainable params: 57,593 (224.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_cnn_gru.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3628 - mae: 0.4109
# Epoch 1: val_loss improved from None to 0.03281, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.1628 - mae: 0.2486 - val_loss: 0.0328 - val_mae: 0.1027
# Epoch 2/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0404 - mae: 0.1349
# Epoch 2: val_loss improved from 0.03281 to 0.01560, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0375 - mae: 0.1304 - val_loss: 0.0156 - val_mae: 0.0764
# Epoch 3/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0272 - mae: 0.1171
# Epoch 3: val_loss improved from 0.01560 to 0.01133, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0259 - mae: 0.1141 - val_loss: 0.0113 - val_mae: 0.0675
# Epoch 4/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0223 - mae: 0.1053
# Epoch 4: val_loss improved from 0.01133 to 0.00914, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0210 - mae: 0.1037 - val_loss: 0.0091 - val_mae: 0.0620
# Epoch 5/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - mae: 0.1018
# Epoch 5: val_loss improved from 0.00914 to 0.00882, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0197 - mae: 0.1008 - val_loss: 0.0088 - val_mae: 0.0603
# Epoch 6/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - mae: 0.0961
# Epoch 6: val_loss improved from 0.00882 to 0.00807, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0181 - mae: 0.0963 - val_loss: 0.0081 - val_mae: 0.0562
# Epoch 7/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - mae: 0.0935
# Epoch 7: val_loss improved from 0.00807 to 0.00803, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0177 - mae: 0.0945 - val_loss: 0.0080 - val_mae: 0.0566
# Epoch 8/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - mae: 0.0925
# Epoch 8: val_loss did not improve from 0.00803
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0167 - mae: 0.0920 - val_loss: 0.0110 - val_mae: 0.0731
# Epoch 9/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - mae: 0.0933
# Epoch 9: val_loss did not improve from 0.00803
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0169 - mae: 0.0933 - val_loss: 0.0085 - val_mae: 0.0601
# Epoch 10/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - mae: 0.0913
# Epoch 10: val_loss improved from 0.00803 to 0.00737, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0164 - mae: 0.0916 - val_loss: 0.0074 - val_mae: 0.0536
# Epoch 11/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mae: 0.0904
# Epoch 11: val_loss improved from 0.00737 to 0.00722, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0163 - mae: 0.0905 - val_loss: 0.0072 - val_mae: 0.0535
# Epoch 12/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - mae: 0.0913
# Epoch 12: val_loss improved from 0.00722 to 0.00700, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0162 - mae: 0.0910 - val_loss: 0.0070 - val_mae: 0.0508
# Epoch 13/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0157 - mae: 0.0893
# Epoch 13: val_loss improved from 0.00700 to 0.00678, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0154 - mae: 0.0889 - val_loss: 0.0068 - val_mae: 0.0505
# Epoch 14/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mae: 0.0889
# Epoch 14: val_loss improved from 0.00678 to 0.00676, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0155 - mae: 0.0889 - val_loss: 0.0068 - val_mae: 0.0499
# Epoch 15/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - mae: 0.0912
# Epoch 15: val_loss did not improve from 0.00676
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0155 - mae: 0.0893 - val_loss: 0.0071 - val_mae: 0.0511
# Epoch 16/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - mae: 0.0861
# Epoch 16: val_loss improved from 0.00676 to 0.00620, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0147 - mae: 0.0864 - val_loss: 0.0062 - val_mae: 0.0464
# Epoch 17/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - mae: 0.0884
# Epoch 17: val_loss did not improve from 0.00620
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0152 - mae: 0.0873 - val_loss: 0.0070 - val_mae: 0.0511
# Epoch 18/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0148 - mae: 0.0875
# Epoch 18: val_loss did not improve from 0.00620
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0151 - mae: 0.0875 - val_loss: 0.0069 - val_mae: 0.0515
# Epoch 19/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - mae: 0.0871
# Epoch 19: val_loss did not improve from 0.00620
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0154 - mae: 0.0879 - val_loss: 0.0073 - val_mae: 0.0547
# Epoch 20/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0146 - mae: 0.0866
# Epoch 20: val_loss did not improve from 0.00620
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0146 - mae: 0.0863 - val_loss: 0.0064 - val_mae: 0.0484
# Epoch 21/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - mae: 0.0863
# Epoch 21: val_loss improved from 0.00620 to 0.00603, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0146 - mae: 0.0862 - val_loss: 0.0060 - val_mae: 0.0466
# Epoch 22/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - mae: 0.0854
# Epoch 22: val_loss did not improve from 0.00603
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.0861 - val_loss: 0.0064 - val_mae: 0.0495
# Epoch 23/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - mae: 0.0845
# Epoch 23: val_loss did not improve from 0.00603
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0146 - mae: 0.0851 - val_loss: 0.0065 - val_mae: 0.0500
# Epoch 24/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - mae: 0.0859
# Epoch 24: val_loss improved from 0.00603 to 0.00562, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.0856 - val_loss: 0.0056 - val_mae: 0.0432
# Epoch 25/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0831
# Epoch 25: val_loss did not improve from 0.00562
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.0841 - val_loss: 0.0061 - val_mae: 0.0467
# Epoch 26/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0832
# Epoch 26: val_loss improved from 0.00562 to 0.00560, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.0846 - val_loss: 0.0056 - val_mae: 0.0429
# Epoch 27/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0816
# Epoch 27: val_loss did not improve from 0.00560
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.0830 - val_loss: 0.0061 - val_mae: 0.0471
# Epoch 28/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0847
# Epoch 28: val_loss did not improve from 0.00560
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.0844 - val_loss: 0.0058 - val_mae: 0.0441
# Epoch 29/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0831
# Epoch 29: val_loss improved from 0.00560 to 0.00549, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.0838 - val_loss: 0.0055 - val_mae: 0.0426
# Epoch 30/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0826
# Epoch 30: val_loss did not improve from 0.00549
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.0837 - val_loss: 0.0055 - val_mae: 0.0424
# Epoch 31/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145 - mae: 0.0839
# Epoch 31: val_loss did not improve from 0.00549
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0136 - mae: 0.0830 - val_loss: 0.0063 - val_mae: 0.0473
# Epoch 32/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0832
# Epoch 32: val_loss improved from 0.00549 to 0.00541, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0136 - mae: 0.0825 - val_loss: 0.0054 - val_mae: 0.0423
# Epoch 33/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0821
# Epoch 33: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0138 - mae: 0.0831 - val_loss: 0.0077 - val_mae: 0.0567
# Epoch 34/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0837
# Epoch 34: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0138 - mae: 0.0832 - val_loss: 0.0066 - val_mae: 0.0485
# Epoch 35/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165 - mae: 0.0843
# Epoch 35: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0136 - mae: 0.0826 - val_loss: 0.0062 - val_mae: 0.0465
# Epoch 36/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0827
# Epoch 36: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0135 - mae: 0.0825 - val_loss: 0.0054 - val_mae: 0.0416
# Epoch 37/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0802
# Epoch 37: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0133 - mae: 0.0817 - val_loss: 0.0056 - val_mae: 0.0427
# Epoch 38/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - mae: 0.0825
# Epoch 38: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0134 - mae: 0.0817 - val_loss: 0.0062 - val_mae: 0.0462
# Epoch 39/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0821
# Epoch 39: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0133 - mae: 0.0819 - val_loss: 0.0057 - val_mae: 0.0422
# Epoch 40/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0827
# Epoch 40: val_loss did not improve from 0.00541
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0135 - mae: 0.0824 - val_loss: 0.0059 - val_mae: 0.0457
# Epoch 41/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0811
# Epoch 41: val_loss improved from 0.00541 to 0.00536, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0132 - mae: 0.0812 - val_loss: 0.0054 - val_mae: 0.0421
# Epoch 42/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0819
# Epoch 42: val_loss did not improve from 0.00536
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0135 - mae: 0.0821 - val_loss: 0.0058 - val_mae: 0.0450
# Epoch 43/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0822
# Epoch 43: val_loss did not improve from 0.00536
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0133 - mae: 0.0815 - val_loss: 0.0056 - val_mae: 0.0436
# Epoch 44/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0809
# Epoch 44: val_loss improved from 0.00536 to 0.00522, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0132 - mae: 0.0815 - val_loss: 0.0052 - val_mae: 0.0400
# Epoch 45/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0792
# Epoch 45: val_loss improved from 0.00522 to 0.00516, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0129 - mae: 0.0807 - val_loss: 0.0052 - val_mae: 0.0403
# Epoch 46/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0808
# Epoch 46: val_loss did not improve from 0.00516
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0134 - mae: 0.0818 - val_loss: 0.0052 - val_mae: 0.0407
# Epoch 47/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0815
# Epoch 47: val_loss did not improve from 0.00516
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0127 - mae: 0.0800 - val_loss: 0.0053 - val_mae: 0.0419
# Epoch 48/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0798
# Epoch 48: val_loss did not improve from 0.00516
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0131 - mae: 0.0811 - val_loss: 0.0053 - val_mae: 0.0407
# Epoch 49/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0811
# Epoch 49: val_loss did not improve from 0.00516
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0130 - mae: 0.0808 - val_loss: 0.0054 - val_mae: 0.0417
# Epoch 50/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mae: 0.0782
# Epoch 50: val_loss improved from 0.00516 to 0.00511, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0128 - mae: 0.0799 - val_loss: 0.0051 - val_mae: 0.0394
# Epoch 51/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0802
# Epoch 51: val_loss did not improve from 0.00511
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0132 - mae: 0.0808 - val_loss: 0.0051 - val_mae: 0.0389
# Epoch 52/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0800
# Epoch 52: val_loss improved from 0.00511 to 0.00506, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0129 - mae: 0.0802 - val_loss: 0.0051 - val_mae: 0.0386
# Epoch 53/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0808
# Epoch 53: val_loss did not improve from 0.00506
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0129 - mae: 0.0807 - val_loss: 0.0058 - val_mae: 0.0449
# Epoch 54/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0791
# Epoch 54: val_loss did not improve from 0.00506
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0126 - mae: 0.0791 - val_loss: 0.0051 - val_mae: 0.0407
# Epoch 55/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0808
# Epoch 55: val_loss did not improve from 0.00506
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0130 - mae: 0.0810 - val_loss: 0.0058 - val_mae: 0.0443
# Epoch 56/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0816
# Epoch 56: val_loss improved from 0.00506 to 0.00489, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0132 - mae: 0.0811 - val_loss: 0.0049 - val_mae: 0.0383
# Epoch 57/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0798
# Epoch 57: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0130 - mae: 0.0804 - val_loss: 0.0051 - val_mae: 0.0388
# Epoch 58/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0812
# Epoch 58: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0128 - mae: 0.0795 - val_loss: 0.0064 - val_mae: 0.0494
# Epoch 59/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mae: 0.0784
# Epoch 59: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0125 - mae: 0.0793 - val_loss: 0.0055 - val_mae: 0.0427
# Epoch 60/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0796
# Epoch 60: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0129 - mae: 0.0798 - val_loss: 0.0050 - val_mae: 0.0392
# Epoch 61/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0787
# Epoch 61: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0128 - mae: 0.0795 - val_loss: 0.0054 - val_mae: 0.0418
# Epoch 62/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - mae: 0.0799
# Epoch 62: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0126 - mae: 0.0789 - val_loss: 0.0049 - val_mae: 0.0385
# Epoch 63/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0793
# Epoch 63: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0124 - mae: 0.0790 - val_loss: 0.0067 - val_mae: 0.0519
# Epoch 64/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mae: 0.0792
# Epoch 64: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0126 - mae: 0.0792 - val_loss: 0.0053 - val_mae: 0.0408
# Epoch 65/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - mae: 0.0802
# Epoch 65: val_loss did not improve from 0.00489
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0130 - mae: 0.0802 - val_loss: 0.0051 - val_mae: 0.0395
# Epoch 66/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0793
# Epoch 66: val_loss improved from 0.00489 to 0.00475, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0130 - mae: 0.0796 - val_loss: 0.0048 - val_mae: 0.0367
# Epoch 67/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0784
# Epoch 67: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0124 - mae: 0.0786 - val_loss: 0.0051 - val_mae: 0.0387
# Epoch 68/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0779
# Epoch 68: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0125 - mae: 0.0787 - val_loss: 0.0050 - val_mae: 0.0370
# Epoch 69/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0802
# Epoch 69: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0127 - mae: 0.0794 - val_loss: 0.0060 - val_mae: 0.0448
# Epoch 70/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0775
# Epoch 70: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0123 - mae: 0.0780 - val_loss: 0.0049 - val_mae: 0.0375
# Epoch 71/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0795
# Epoch 71: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0125 - mae: 0.0788 - val_loss: 0.0048 - val_mae: 0.0371
# Epoch 72/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - mae: 0.0807
# Epoch 72: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0127 - mae: 0.0795 - val_loss: 0.0050 - val_mae: 0.0376
# Epoch 73/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0776
# Epoch 73: val_loss improved from 0.00475 to 0.00474, saving model to best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0126 - mae: 0.0788 - val_loss: 0.0047 - val_mae: 0.0357
# Epoch 74/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0782
# Epoch 74: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0125 - mae: 0.0788 - val_loss: 0.0048 - val_mae: 0.0369
# Epoch 75/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0777
# Epoch 75: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0123 - mae: 0.0780 - val_loss: 0.0048 - val_mae: 0.0378
# Epoch 76/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0781
# Epoch 76: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0124 - mae: 0.0783 - val_loss: 0.0052 - val_mae: 0.0406
# Epoch 77/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0793
# Epoch 77: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0124 - mae: 0.0785 - val_loss: 0.0049 - val_mae: 0.0366
# Epoch 78/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0781
# Epoch 78: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0124 - mae: 0.0783 - val_loss: 0.0048 - val_mae: 0.0379
# Epoch 79/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0784
# Epoch 79: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0124 - mae: 0.0785 - val_loss: 0.0048 - val_mae: 0.0375
# Epoch 80/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mae: 0.0785
# Epoch 80: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0123 - mae: 0.0784 - val_loss: 0.0050 - val_mae: 0.0380
# Epoch 81/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0780
# Epoch 81: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0127 - mae: 0.0790 - val_loss: 0.0049 - val_mae: 0.0368
# Epoch 82/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0785
# Epoch 82: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0124 - mae: 0.0782 - val_loss: 0.0048 - val_mae: 0.0366
# Epoch 83/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0786
# Epoch 83: val_loss did not improve from 0.00474
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0123 - mae: 0.0783 - val_loss: 0.0048 - val_mae: 0.0372

# %%
test_loss, test_mae = model.evaluate([X_ic_test, X_context_test], y_test, verbose=1)
print(f"Test MAE (normalized): {test_mae:.4f}")
print(f"Test MSE (normalized): {test_loss:.4f}")

# Inverse transform MAE to original units
test_mae_real = test_mae * y_std
print(f"Test MAE (original SOH units): {test_mae_real:.4f}")

# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE over Epochs')

plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0350
# Test MAE (normalized): 0.0350
# Test MSE (normalized): 0.0026
# Test MAE (original SOH units): 0.2325

# %%
import matplotlib.pyplot as plt

y_pred = model.predict([X_ic_test, X_context_test]).flatten()

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+GRU SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
r2 = r2_score(y_test, y_pred)

print(f"R-squared (normalized): {r2:.4f}")

y_test_real = y_test * y_std + y_mean
y_pred_real = y_pred * y_std + y_mean

r2_real = r2_score(y_test_real, y_pred_real)
print(f"R-squared (original SOH units): {r2_real:.4f}")
# Out:
# R-squared (normalized): 0.9974
# R-squared (original SOH units): 0.9974

# %%
X_ic_test_25 = []
X_context_test_25 = []
X_ic_test_35 = []
X_context_test_35 = []
X_ic_test_45 = []
X_context_test_45 = []
y_test_25 = []
y_test_35 = []  
y_test_45 = []

for i in range(X_context_test.shape[0]):
    if X_context_test[i, 1] > 0:      # temp_25 one-hot
        X_ic_test_25.append(X_ic_test[i])
        X_context_test_25.append(X_context_test[i])
        y_test_25.append(y_test[i])
    if X_context_test[i, 2] > 0:      # temp_35 one-hot
        X_ic_test_35.append(X_ic_test[i])
        X_context_test_35.append(X_context_test[i])
        y_test_35.append(y_test[i])
    if X_context_test[i, 3] > 0:      # temp_45 one-hot
        X_ic_test_45.append(X_ic_test[i])
        X_context_test_45.append(X_context_test[i])
        y_test_45.append(y_test[i])

X_ic_test_25 = np.array(X_ic_test_25)
X_ic_test_35 = np.array(X_ic_test_35)
X_ic_test_45 = np.array(X_ic_test_45)

X_context_test_25 = np.array(X_context_test_25)
X_context_test_35 = np.array(X_context_test_35)
X_context_test_45 = np.array(X_context_test_45)

y_test_25 = np.array(y_test_25)
y_test_35 = np.array(y_test_35)
y_test_45 = np.array(y_test_45)

print(X_ic_test_25.shape)
print(X_ic_test_35.shape)
print(X_ic_test_45.shape)

print(X_context_test_25.shape)
print(X_context_test_35.shape)
print(X_context_test_45.shape)


print(y_test_25.shape)
print(y_test_35.shape)
print(y_test_45.shape)
# Out:
# (1162, 20, 1)
# (235, 20, 1)
# (3131, 20, 1)
# (1162, 7)
# (235, 7)
# (3131, 7)
# (1162,)
# (235,)
# (3131,)

# %%
X_ic_test_25_seq = np.expand_dims(X_ic_test_25, axis=2)
X_ic_test_35_seq = np.expand_dims(X_ic_test_35, axis=2)
X_ic_test_45_seq = np.expand_dims(X_ic_test_45, axis=2)
print(X_ic_test_25_seq.shape)
print(X_ic_test_35_seq.shape)
print(X_ic_test_45_seq.shape)
# Out:
# (1162, 20, 1, 1)
# (235, 20, 1, 1)
# (3131, 20, 1, 1)

# %%
cnn_gru = keras.models.load_model(r'F:\College\SEM 8\Project Phase 2\Models\best_cnn_gru.keras')

# %%
y_pred_25_scaled = cnn_gru.predict([X_ic_test_25_seq, X_context_test_25]).flatten()
y_pred_35_scaled = cnn_gru.predict([X_ic_test_35_seq, X_context_test_35]).flatten()
y_pred_45_scaled = cnn_gru.predict([X_ic_test_45_seq, X_context_test_45]).flatten()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred_25 = y_pred_25_scaled * y_std + y_mean
y_pred_35 = y_pred_35_scaled * y_std + y_mean
y_pred_45 = y_pred_45_scaled * y_std + y_mean

y_true_25 = y_test_25 * y_std + y_mean
y_true_35 = y_test_35 * y_std + y_mean
y_true_45 = y_test_45 * y_std + y_mean

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def metrics(y_t, y_p):
    return (mean_absolute_error(y_t, y_p),
            mean_squared_error(y_t, y_p),
            r2_score(y_t, y_p))

mae_25, mse_25, r2_25 = metrics(y_true_25, y_pred_25)
print("25C → MAE:", mae_25, "MSE:", mse_25, "R²:", r2_25)


mae_35, mse_35, r2_35 = metrics(y_true_35, y_pred_35)
print("35C → MAE:", mae_35, "MSE:", mse_35, "R²:", r2_35)

mae_45, mse_45, r2_45 = metrics(y_true_45, y_pred_45)
print("45C → MAE:", mae_45, "MSE:", mse_45, "R²:", r2_45)
# Out:
# 25C → MAE: 0.3384154259313015 MSE: 0.20093530147021915 R²: 0.9942960912163278
# 35C → MAE: 0.1434761247171894 MSE: 0.05158220721722169 R²: 0.9983830952363965
# 45C → MAE: 0.1998356566354051 MSE: 0.08992552775456908 R²: 0.997713942115486

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scatter(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=0.6, s=15)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    plt.title(title, fontsize=14)
    plt.xlabel("True SOH", fontsize=12)
    plt.ylabel("Predicted SOH", fontsize=12)
    plt.grid(True)

# %%
plt.figure(figsize=(22,6))

plt.subplot(1,3,1)
plot_scatter(y_true_25, y_pred_25, "SOH Prediction @ 25°C")

plt.subplot(1,3,2)
plot_scatter(y_true_35, y_pred_35, "SOH Prediction @ 35°C")

plt.subplot(1,3,3)
plot_scatter(y_true_45, y_pred_45, "SOH Prediction @ 45°C")

plt.show()
