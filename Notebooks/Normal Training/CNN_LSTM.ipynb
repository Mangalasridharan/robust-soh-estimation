# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r'../../Dataset/NCA Preprocessed/master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
import sys
sys.path.append("../../")
from preprocessing.data_preprocessor import DataPreprocessor


preprocessor = DataPreprocessor(
    train_size=0.8,
    ic_low=0,
    ic_high=20
)

data = preprocessor.preprocess(df)

X_ic_train = data["X_ic_train"]
X_context_train = data["X_context_train"]
y_train = data["y_train"]


print("Train Data shape:")
print("X_ic_train shape:", X_ic_train.shape)
print("X_context_train shape:", X_context_train.shape)
print("y_train shape:",y_train.shape)
# Out:
# Train Data shape:
# X_ic_train shape: (18109, 20, 1)
# X_context_train shape: (18109, 7)
# y_train shape: (18109,)

# %%
# -------------------------
# IC Input (20 timesteps, 1 channel)
# -------------------------
ic_input = Input(shape=(X_ic_train.shape[1], X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=64, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = LSTM(64)(x)

# -------------------------
# Context Input (cycle_scaled + temp one-hot + charge one-hot)
# -------------------------
context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

# -------------------------
# Combine IC latent + Context latent
# -------------------------
combined = Concatenate()([x, c])

# -------------------------
# Final dense layers
# -------------------------
z = Dense(64, activation='relu')(combined)
z = Dropout(0.3)(z)
output = Dense(1, activation='linear')(z)

# -------------------------
# Build model
# -------------------------
model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 64)     │     12,352 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 64)     │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     33,024 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 96)        │          0 │ lstm[0][0],       │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      6,208 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 52,161 (203.75 KB)
#  Trainable params: 52,161 (203.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('../../Models/CNN_LSTM_NT.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4455 - mae: 0.4859
# Epoch 1: val_loss improved from None to 0.03933, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.2125 - mae: 0.3075 - val_loss: 0.0393 - val_mae: 0.1174
# Epoch 2/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0647 - mae: 0.1756
# Epoch 2: val_loss improved from 0.03933 to 0.02387, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0608 - mae: 0.1690 - val_loss: 0.0239 - val_mae: 0.0896
# Epoch 3/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0456 - mae: 0.1517
# Epoch 3: val_loss improved from 0.02387 to 0.01570, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0436 - mae: 0.1482 - val_loss: 0.0157 - val_mae: 0.0781
# Epoch 4/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0352 - mae: 0.1348
# Epoch 4: val_loss improved from 0.01570 to 0.01267, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0340 - mae: 0.1315 - val_loss: 0.0127 - val_mae: 0.0738
# Epoch 5/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298 - mae: 0.1248
# Epoch 5: val_loss improved from 0.01267 to 0.01090, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0301 - mae: 0.1249 - val_loss: 0.0109 - val_mae: 0.0693
# Epoch 6/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0281 - mae: 0.1217
# Epoch 6: val_loss improved from 0.01090 to 0.00905, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0272 - mae: 0.1190 - val_loss: 0.0091 - val_mae: 0.0611
# Epoch 7/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0260 - mae: 0.1159
# Epoch 7: val_loss improved from 0.00905 to 0.00871, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0258 - mae: 0.1148 - val_loss: 0.0087 - val_mae: 0.0608
# Epoch 8/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0244 - mae: 0.1121
# Epoch 8: val_loss did not improve from 0.00871
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0248 - mae: 0.1126 - val_loss: 0.0094 - val_mae: 0.0647
# Epoch 9/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0239 - mae: 0.1113
# Epoch 9: val_loss did not improve from 0.00871
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0245 - mae: 0.1118 - val_loss: 0.0095 - val_mae: 0.0664
# Epoch 10/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0246 - mae: 0.1117
# Epoch 10: val_loss did not improve from 0.00871
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0236 - mae: 0.1105 - val_loss: 0.0088 - val_mae: 0.0620
# Epoch 11/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226 - mae: 0.1079
# Epoch 11: val_loss improved from 0.00871 to 0.00796, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0226 - mae: 0.1078 - val_loss: 0.0080 - val_mae: 0.0575
# Epoch 12/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - mae: 0.1073
# Epoch 12: val_loss did not improve from 0.00796
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0228 - mae: 0.1079 - val_loss: 0.0081 - val_mae: 0.0585
# Epoch 13/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227 - mae: 0.1065
# Epoch 13: val_loss improved from 0.00796 to 0.00717, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0222 - mae: 0.1060 - val_loss: 0.0072 - val_mae: 0.0529
# Epoch 14/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0225 - mae: 0.1071
# Epoch 14: val_loss did not improve from 0.00717
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0218 - mae: 0.1058 - val_loss: 0.0078 - val_mae: 0.0569
# Epoch 15/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0220 - mae: 0.1061
# Epoch 15: val_loss did not improve from 0.00717
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0221 - mae: 0.1058 - val_loss: 0.0077 - val_mae: 0.0561
# Epoch 16/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0217 - mae: 0.1049
# Epoch 16: val_loss improved from 0.00717 to 0.00659, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0215 - mae: 0.1046 - val_loss: 0.0066 - val_mae: 0.0498
# Epoch 17/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - mae: 0.1064
# Epoch 17: val_loss did not improve from 0.00659
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0219 - mae: 0.1055 - val_loss: 0.0082 - val_mae: 0.0594
# Epoch 18/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - mae: 0.1065
# Epoch 18: val_loss did not improve from 0.00659
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0218 - mae: 0.1048 - val_loss: 0.0071 - val_mae: 0.0532
# Epoch 19/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0208 - mae: 0.1029
# Epoch 19: val_loss improved from 0.00659 to 0.00651, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0210 - mae: 0.1030 - val_loss: 0.0065 - val_mae: 0.0496
# Epoch 20/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211 - mae: 0.1033
# Epoch 20: val_loss did not improve from 0.00651
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0213 - mae: 0.1037 - val_loss: 0.0070 - val_mae: 0.0525
# Epoch 21/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - mae: 0.1043
# Epoch 21: val_loss improved from 0.00651 to 0.00624, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0214 - mae: 0.1038 - val_loss: 0.0062 - val_mae: 0.0475
# Epoch 22/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - mae: 0.1013
# Epoch 22: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0208 - mae: 0.1025 - val_loss: 0.0074 - val_mae: 0.0543
# Epoch 23/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0202 - mae: 0.1014
# Epoch 23: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0204 - mae: 0.1014 - val_loss: 0.0073 - val_mae: 0.0546
# Epoch 24/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0209 - mae: 0.1024
# Epoch 24: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0206 - mae: 0.1021 - val_loss: 0.0083 - val_mae: 0.0612
# Epoch 25/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - mae: 0.1008
# Epoch 25: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0202 - mae: 0.1010 - val_loss: 0.0064 - val_mae: 0.0494
# Epoch 26/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0199 - mae: 0.1006
# Epoch 26: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0200 - mae: 0.1010 - val_loss: 0.0067 - val_mae: 0.0514
# Epoch 27/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0197 - mae: 0.1001
# Epoch 27: val_loss did not improve from 0.00624
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0203 - mae: 0.1009 - val_loss: 0.0071 - val_mae: 0.0541
# Epoch 28/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - mae: 0.1024
# Epoch 28: val_loss improved from 0.00624 to 0.00619, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0201 - mae: 0.1007 - val_loss: 0.0062 - val_mae: 0.0483
# Epoch 29/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0211 - mae: 0.1020
# Epoch 29: val_loss did not improve from 0.00619
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0205 - mae: 0.1014 - val_loss: 0.0072 - val_mae: 0.0523
# Epoch 30/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0205 - mae: 0.1010
# Epoch 30: val_loss did not improve from 0.00619
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0205 - mae: 0.1008 - val_loss: 0.0077 - val_mae: 0.0571
# Epoch 31/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - mae: 0.1017
# Epoch 31: val_loss did not improve from 0.00619
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0205 - mae: 0.1013 - val_loss: 0.0066 - val_mae: 0.0507
# Epoch 32/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - mae: 0.0990
# Epoch 32: val_loss improved from 0.00619 to 0.00583, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0198 - mae: 0.0998 - val_loss: 0.0058 - val_mae: 0.0445
# Epoch 33/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - mae: 0.1007
# Epoch 33: val_loss did not improve from 0.00583
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0199 - mae: 0.0999 - val_loss: 0.0061 - val_mae: 0.0470
# Epoch 34/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - mae: 0.1010
# Epoch 34: val_loss did not improve from 0.00583
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0204 - mae: 0.1002 - val_loss: 0.0060 - val_mae: 0.0463
# Epoch 35/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - mae: 0.0990
# Epoch 35: val_loss improved from 0.00583 to 0.00581, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0201 - mae: 0.1001 - val_loss: 0.0058 - val_mae: 0.0453
# Epoch 36/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - mae: 0.0986
# Epoch 36: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0196 - mae: 0.0991 - val_loss: 0.0059 - val_mae: 0.0447
# Epoch 37/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - mae: 0.1001
# Epoch 37: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0197 - mae: 0.0995 - val_loss: 0.0062 - val_mae: 0.0478
# Epoch 38/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - mae: 0.0990
# Epoch 38: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0194 - mae: 0.0990 - val_loss: 0.0062 - val_mae: 0.0482
# Epoch 39/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0193 - mae: 0.0998
# Epoch 39: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0200 - mae: 0.1008 - val_loss: 0.0059 - val_mae: 0.0455
# Epoch 40/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0197 - mae: 0.0995
# Epoch 40: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0199 - mae: 0.1000 - val_loss: 0.0060 - val_mae: 0.0465
# Epoch 41/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - mae: 0.0988
# Epoch 41: val_loss did not improve from 0.00581
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0194 - mae: 0.0982 - val_loss: 0.0060 - val_mae: 0.0468
# Epoch 42/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196 - mae: 0.0989
# Epoch 42: val_loss improved from 0.00581 to 0.00573, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0197 - mae: 0.0990 - val_loss: 0.0057 - val_mae: 0.0446
# Epoch 43/100
# 440/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - mae: 0.1012
# Epoch 43: val_loss improved from 0.00573 to 0.00565, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0202 - mae: 0.1005 - val_loss: 0.0057 - val_mae: 0.0437
# Epoch 44/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0200 - mae: 0.1001
# Epoch 44: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0203 - mae: 0.1009 - val_loss: 0.0064 - val_mae: 0.0492
# Epoch 45/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191 - mae: 0.0987
# Epoch 45: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0199 - mae: 0.0996 - val_loss: 0.0067 - val_mae: 0.0499
# Epoch 46/100
# 440/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197 - mae: 0.0990
# Epoch 46: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0198 - mae: 0.0988 - val_loss: 0.0062 - val_mae: 0.0479
# Epoch 47/100
# 437/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188 - mae: 0.0980
# Epoch 47: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0192 - mae: 0.0984 - val_loss: 0.0057 - val_mae: 0.0432
# Epoch 48/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - mae: 0.0991
# Epoch 48: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0194 - mae: 0.0985 - val_loss: 0.0061 - val_mae: 0.0475
# Epoch 49/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194 - mae: 0.0983
# Epoch 49: val_loss did not improve from 0.00565
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0191 - mae: 0.0975 - val_loss: 0.0064 - val_mae: 0.0489
# Epoch 50/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189 - mae: 0.0976
# Epoch 50: val_loss improved from 0.00565 to 0.00543, saving model to ../../Models/CNN_LSTM_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0198 - mae: 0.0988 - val_loss: 0.0054 - val_mae: 0.0420
# Epoch 51/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198 - mae: 0.0998
# Epoch 51: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0195 - mae: 0.0990 - val_loss: 0.0058 - val_mae: 0.0440
# Epoch 52/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190 - mae: 0.0986
# Epoch 52: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0194 - mae: 0.0983 - val_loss: 0.0058 - val_mae: 0.0436
# Epoch 53/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0200 - mae: 0.0980
# Epoch 53: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0193 - mae: 0.0979 - val_loss: 0.0062 - val_mae: 0.0470
# Epoch 54/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191 - mae: 0.0983
# Epoch 54: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0194 - mae: 0.0987 - val_loss: 0.0055 - val_mae: 0.0421
# Epoch 55/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192 - mae: 0.0984
# Epoch 55: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0190 - mae: 0.0975 - val_loss: 0.0058 - val_mae: 0.0439
# Epoch 56/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - mae: 0.0979
# Epoch 56: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0189 - mae: 0.0973 - val_loss: 0.0064 - val_mae: 0.0485
# Epoch 57/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - mae: 0.0979
# Epoch 57: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0189 - mae: 0.0976 - val_loss: 0.0063 - val_mae: 0.0482
# Epoch 58/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - mae: 0.0977
# Epoch 58: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0189 - mae: 0.0971 - val_loss: 0.0056 - val_mae: 0.0428
# Epoch 59/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - mae: 0.0955
# Epoch 59: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0189 - mae: 0.0969 - val_loss: 0.0056 - val_mae: 0.0430
# Epoch 60/100
# 438/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - mae: 0.0988
# Epoch 60: val_loss did not improve from 0.00543
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0188 - mae: 0.0969 - val_loss: 0.0055 - val_mae: 0.0419

# %%
# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE over Epochs')

plt.show()

# %%
X_ic_test = data['X_ic_test']
X_context_test = data['X_context_test']
y_test_norm = data['y_test']

y_mean = data['y_mean']
y_std = data['y_std']

print("Test data shape:")
print("X_ic_test shape:", X_ic_test.shape)
print("X_context_test shape:", X_context_test.shape)
print("Y_test shape:", y_test_norm.shape)
# Out:
# Test data shape:
# X_ic_test shape: (4528, 20, 1)
# X_context_test shape: (4528, 7)
# Y_test shape: (4528,)

# %%
import matplotlib.pyplot as plt

y_pred_norm = model.predict([X_ic_test, X_context_test]).flatten()

y_pred = y_pred_norm * y_std + y_mean
y_test = y_test_norm * y_std + y_mean

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+LSTM NT SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
cnn_lstm = keras.models.load_model(r'../../Models/CNN_LSTM_NT.keras')

# %%
from utils.data_split import temp_based_split

data = temp_based_split(X_ic_test, X_context_test, y_test_norm)
# Out:
# -----25 degree Celsius-----
# X_ic shape: (1162, 20, 1)
# X_context shape: (1162, 7)
# y_test shape: (1162,)
#
# -----35 degree Celsius-----
# X_ic shape: (235, 20, 1)
# X_context shape: (235, 7)
# y_test shape: (235,)
#
# -----45 degree Celsius-----
# X_ic shape: (3131, 20, 1)
# X_context shape: (3131, 7)
# y_test shape: (3131,)

# %%
from utils.predict import make_predictions

predicitons, true, metrics = make_predictions(cnn_lstm, data, y_mean, y_std)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from utils.plots import scatter_plot

scatter_plot(predicitons, true, y_std, y_mean, model_name="CNN+LSTM NT")

# %%
from utils.metrics import get_metrics, format_metrics

metrics = get_metrics(predicitons, true, y_mean, y_std)

format_metrics(metrics, model_name="CNN+LSTM NT")
# Out:
# ============================================================
# CNN+LSTM NT Metrics - NORMALIZED
# ============================================================
#
# +---------------+----------+----------+----------+------------+
# | Temperature   |      MAE |      MSE |     RMSE |   R2 Score |
# +===============+==========+==========+==========+============+
# | 25            | 0.060537 | 0.006844 | 0.082728 |   0.991414 |
# +---------------+----------+----------+----------+------------+
# | 35            | 0.029886 | 0.001402 | 0.037447 |   0.998057 |
# +---------------+----------+----------+----------+------------+
# | 45            | 0.034537 | 0.002432 | 0.049315 |   0.997268 |
# +---------------+----------+----------+----------+------------+
# | complete      | 0.040968 | 0.003511 | 0.059252 |   0.996499 |
# +---------------+----------+----------+----------+------------+
#
#
# ============================================================
# CNN+LSTM NT Metrics - ORIGINAL
# ============================================================
#
# +---------------+----------+----------+----------+------------+
# | Temperature   |      MAE |      MSE |     RMSE |   R2 Score |
# +===============+==========+==========+==========+============+
# | 25            | 0.402439 | 0.302462 | 0.082728 |   0.991414 |
# +---------------+----------+----------+----------+------------+
# | 35            | 0.198679 | 0.061974 | 0.037447 |   0.998057 |
# +---------------+----------+----------+----------+------------+
# | 45            | 0.229596 | 0.107479 | 0.049315 |   0.997268 |
# +---------------+----------+----------+----------+------------+
# | complete      | 0.272347 | 0.155155 | 0.059252 |   0.996499 |
# +---------------+----------+----------+----------+------------+
