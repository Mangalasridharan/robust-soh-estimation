# %%
import sys
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r'../../Dataset/NCA Preprocessed/master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
sys.path.append("../../")
from preprocessing.data_preprocessor import DataPreprocessor


preprocessor = DataPreprocessor(
    train_size=0.8,
    ic_low=0,
    ic_high=20
)

data = preprocessor.preprocess(df)

X_ic_train = data["X_ic_train"]
X_context_train = data["X_context_train"]
y_train = data["y_train"]


print("Train Data shape:")
print("X_ic_train shape:", X_ic_train.shape)
print("X_context_train shape:", X_context_train.shape)
print("y_train shape:",y_train.shape)
# Out:
# Train Data shape:
# X_ic_train shape: (18109, 20, 1)
# X_context_train shape: (18109, 7)
# y_train shape: (18109,)

# %%
ic_input = Input(shape=(X_ic_train.shape[1],X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=128, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = GRU(units=50, return_sequences=False)(x)

context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

combined = Concatenate()([x,c])

z = Dense(64, activation='relu')(combined)
z = Dropout(0.2)(z)
output = Dense(1, activation='linear')(z)

model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 128)    │     24,704 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 128)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 50)        │     27,000 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 82)        │          0 │ gru[0][0],        │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      5,312 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 57,593 (224.97 KB)
#  Trainable params: 57,593 (224.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('../../Models/best_cnn_gru.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3596 - mae: 0.4213
# Epoch 1: val_loss improved from None to 0.04323, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.1767 - mae: 0.2661 - val_loss: 0.0432 - val_mae: 0.1151
# Epoch 2/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0540 - mae: 0.1508
# Epoch 2: val_loss improved from 0.04323 to 0.02317, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0473 - mae: 0.1418 - val_loss: 0.0232 - val_mae: 0.0853
# Epoch 3/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0335 - mae: 0.1250
# Epoch 3: val_loss improved from 0.02317 to 0.01388, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0308 - mae: 0.1209 - val_loss: 0.0139 - val_mae: 0.0715
# Epoch 4/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0236 - mae: 0.1087
# Epoch 4: val_loss improved from 0.01388 to 0.01114, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0226 - mae: 0.1065 - val_loss: 0.0111 - val_mae: 0.0687
# Epoch 5/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0196 - mae: 0.1005
# Epoch 5: val_loss improved from 0.01114 to 0.00849, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0193 - mae: 0.0997 - val_loss: 0.0085 - val_mae: 0.0594
# Epoch 6/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - mae: 0.0974
# Epoch 6: val_loss improved from 0.00849 to 0.00774, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0178 - mae: 0.0963 - val_loss: 0.0077 - val_mae: 0.0563
# Epoch 7/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0163 - mae: 0.0936
# Epoch 7: val_loss did not improve from 0.00774
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0167 - mae: 0.0931 - val_loss: 0.0078 - val_mae: 0.0576
# Epoch 8/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0156 - mae: 0.0911
# Epoch 8: val_loss did not improve from 0.00774
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0158 - mae: 0.0906 - val_loss: 0.0086 - val_mae: 0.0609
# Epoch 9/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159 - mae: 0.0904
# Epoch 9: val_loss did not improve from 0.00774
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0157 - mae: 0.0898 - val_loss: 0.0084 - val_mae: 0.0584
# Epoch 10/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - mae: 0.0901
# Epoch 10: val_loss improved from 0.00774 to 0.00709, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0155 - mae: 0.0887 - val_loss: 0.0071 - val_mae: 0.0513
# Epoch 11/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - mae: 0.0887
# Epoch 11: val_loss improved from 0.00709 to 0.00667, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0152 - mae: 0.0878 - val_loss: 0.0067 - val_mae: 0.0499
# Epoch 12/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - mae: 0.0881
# Epoch 12: val_loss improved from 0.00667 to 0.00637, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0147 - mae: 0.0872 - val_loss: 0.0064 - val_mae: 0.0485
# Epoch 13/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0148 - mae: 0.0872
# Epoch 13: val_loss did not improve from 0.00637
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0149 - mae: 0.0869 - val_loss: 0.0068 - val_mae: 0.0511
# Epoch 14/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0145 - mae: 0.0857
# Epoch 14: val_loss did not improve from 0.00637
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0145 - mae: 0.0860 - val_loss: 0.0069 - val_mae: 0.0513
# Epoch 15/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145 - mae: 0.0865
# Epoch 15: val_loss did not improve from 0.00637
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0148 - mae: 0.0861 - val_loss: 0.0066 - val_mae: 0.0509
# Epoch 16/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mae: 0.0842
# Epoch 16: val_loss improved from 0.00637 to 0.00635, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0141 - mae: 0.0847 - val_loss: 0.0064 - val_mae: 0.0490
# Epoch 17/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - mae: 0.0866
# Epoch 17: val_loss improved from 0.00635 to 0.00599, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0143 - mae: 0.0853 - val_loss: 0.0060 - val_mae: 0.0465
# Epoch 18/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0149 - mae: 0.0863
# Epoch 18: val_loss did not improve from 0.00599
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0145 - mae: 0.0856 - val_loss: 0.0073 - val_mae: 0.0550
# Epoch 19/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0848
# Epoch 19: val_loss did not improve from 0.00599
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0141 - mae: 0.0842 - val_loss: 0.0062 - val_mae: 0.0480
# Epoch 20/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - mae: 0.0847
# Epoch 20: val_loss did not improve from 0.00599
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0139 - mae: 0.0839 - val_loss: 0.0063 - val_mae: 0.0493
# Epoch 21/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0820
# Epoch 21: val_loss improved from 0.00599 to 0.00570, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0134 - mae: 0.0822 - val_loss: 0.0057 - val_mae: 0.0448
# Epoch 22/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139 - mae: 0.0837
# Epoch 22: val_loss did not improve from 0.00570
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0140 - mae: 0.0840 - val_loss: 0.0063 - val_mae: 0.0492
# Epoch 23/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0824
# Epoch 23: val_loss improved from 0.00570 to 0.00555, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0130 - mae: 0.0817 - val_loss: 0.0056 - val_mae: 0.0439
# Epoch 24/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0144 - mae: 0.0837
# Epoch 24: val_loss did not improve from 0.00555
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0135 - mae: 0.0824 - val_loss: 0.0066 - val_mae: 0.0495
# Epoch 25/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131 - mae: 0.0827
# Epoch 25: val_loss improved from 0.00555 to 0.00554, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0135 - mae: 0.0825 - val_loss: 0.0055 - val_mae: 0.0443
# Epoch 26/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mae: 0.0807
# Epoch 26: val_loss did not improve from 0.00554
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0133 - mae: 0.0819 - val_loss: 0.0059 - val_mae: 0.0461
# Epoch 27/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0805
# Epoch 27: val_loss did not improve from 0.00554
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0130 - mae: 0.0809 - val_loss: 0.0062 - val_mae: 0.0457
# Epoch 28/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0821
# Epoch 28: val_loss did not improve from 0.00554
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0132 - mae: 0.0814 - val_loss: 0.0059 - val_mae: 0.0434
# Epoch 29/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - mae: 0.0818
# Epoch 29: val_loss improved from 0.00554 to 0.00534, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0132 - mae: 0.0813 - val_loss: 0.0053 - val_mae: 0.0426
# Epoch 30/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - mae: 0.0790
# Epoch 30: val_loss did not improve from 0.00534
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0127 - mae: 0.0801 - val_loss: 0.0061 - val_mae: 0.0487
# Epoch 31/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123 - mae: 0.0804
# Epoch 31: val_loss did not improve from 0.00534
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0130 - mae: 0.0813 - val_loss: 0.0060 - val_mae: 0.0483
# Epoch 32/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - mae: 0.0809
# Epoch 32: val_loss did not improve from 0.00534
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0129 - mae: 0.0806 - val_loss: 0.0060 - val_mae: 0.0491
# Epoch 33/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mae: 0.0803
# Epoch 33: val_loss improved from 0.00534 to 0.00508, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0128 - mae: 0.0803 - val_loss: 0.0051 - val_mae: 0.0415
# Epoch 34/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127 - mae: 0.0805
# Epoch 34: val_loss did not improve from 0.00508
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0129 - mae: 0.0807 - val_loss: 0.0056 - val_mae: 0.0458
# Epoch 35/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0132 - mae: 0.0795
# Epoch 35: val_loss did not improve from 0.00508
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0123 - mae: 0.0792 - val_loss: 0.0055 - val_mae: 0.0429
# Epoch 36/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0126 - mae: 0.0808
# Epoch 36: val_loss did not improve from 0.00508
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0128 - mae: 0.0801 - val_loss: 0.0055 - val_mae: 0.0447
# Epoch 37/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0122 - mae: 0.0799
# Epoch 37: val_loss did not improve from 0.00508
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0125 - mae: 0.0796 - val_loss: 0.0053 - val_mae: 0.0420
# Epoch 38/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126 - mae: 0.0799
# Epoch 38: val_loss did not improve from 0.00508
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0125 - mae: 0.0798 - val_loss: 0.0052 - val_mae: 0.0415
# Epoch 39/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mae: 0.0805
# Epoch 39: val_loss improved from 0.00508 to 0.00487, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0126 - mae: 0.0795 - val_loss: 0.0049 - val_mae: 0.0406
# Epoch 40/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - mae: 0.0804
# Epoch 40: val_loss did not improve from 0.00487
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0128 - mae: 0.0802 - val_loss: 0.0058 - val_mae: 0.0477
# Epoch 41/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - mae: 0.0796
# Epoch 41: val_loss did not improve from 0.00487
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0125 - mae: 0.0791 - val_loss: 0.0049 - val_mae: 0.0404
# Epoch 42/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0121 - mae: 0.0791
# Epoch 42: val_loss did not improve from 0.00487
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0122 - mae: 0.0785 - val_loss: 0.0049 - val_mae: 0.0404
# Epoch 43/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - mae: 0.0796
# Epoch 43: val_loss did not improve from 0.00487
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0126 - mae: 0.0796 - val_loss: 0.0055 - val_mae: 0.0444
# Epoch 44/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mae: 0.0796
# Epoch 44: val_loss did not improve from 0.00487
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0123 - mae: 0.0789 - val_loss: 0.0050 - val_mae: 0.0410
# Epoch 45/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0774
# Epoch 45: val_loss improved from 0.00487 to 0.00478, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0774 - val_loss: 0.0048 - val_mae: 0.0393
# Epoch 46/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - mae: 0.0779
# Epoch 46: val_loss improved from 0.00478 to 0.00477, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0120 - mae: 0.0781 - val_loss: 0.0048 - val_mae: 0.0395
# Epoch 47/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - mae: 0.0802
# Epoch 47: val_loss improved from 0.00477 to 0.00469, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0124 - mae: 0.0793 - val_loss: 0.0047 - val_mae: 0.0398
# Epoch 48/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - mae: 0.0786
# Epoch 48: val_loss did not improve from 0.00469
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0122 - mae: 0.0784 - val_loss: 0.0055 - val_mae: 0.0450
# Epoch 49/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0786
# Epoch 49: val_loss did not improve from 0.00469
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0120 - mae: 0.0777 - val_loss: 0.0050 - val_mae: 0.0412
# Epoch 50/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mae: 0.0774
# Epoch 50: val_loss improved from 0.00469 to 0.00460, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0121 - mae: 0.0778 - val_loss: 0.0046 - val_mae: 0.0385
# Epoch 51/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - mae: 0.0774
# Epoch 51: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0776 - val_loss: 0.0054 - val_mae: 0.0445
# Epoch 52/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - mae: 0.0765
# Epoch 52: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0119 - mae: 0.0776 - val_loss: 0.0052 - val_mae: 0.0440
# Epoch 53/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0780
# Epoch 53: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0120 - mae: 0.0777 - val_loss: 0.0048 - val_mae: 0.0395
# Epoch 54/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0779
# Epoch 54: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0120 - mae: 0.0776 - val_loss: 0.0056 - val_mae: 0.0466
# Epoch 55/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mae: 0.0779
# Epoch 55: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0774 - val_loss: 0.0047 - val_mae: 0.0382
# Epoch 56/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0784
# Epoch 56: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0121 - mae: 0.0776 - val_loss: 0.0051 - val_mae: 0.0410
# Epoch 57/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0784
# Epoch 57: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0120 - mae: 0.0780 - val_loss: 0.0046 - val_mae: 0.0387
# Epoch 58/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mae: 0.0764
# Epoch 58: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0115 - mae: 0.0767 - val_loss: 0.0047 - val_mae: 0.0390
# Epoch 59/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - mae: 0.0783
# Epoch 59: val_loss did not improve from 0.00460
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0120 - mae: 0.0777 - val_loss: 0.0062 - val_mae: 0.0485
# Epoch 60/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - mae: 0.0773
# Epoch 60: val_loss improved from 0.00460 to 0.00459, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0766 - val_loss: 0.0046 - val_mae: 0.0384
# Epoch 61/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mae: 0.0768
# Epoch 61: val_loss did not improve from 0.00459
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0116 - mae: 0.0763 - val_loss: 0.0049 - val_mae: 0.0406
# Epoch 62/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0768
# Epoch 62: val_loss improved from 0.00459 to 0.00452, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0119 - mae: 0.0769 - val_loss: 0.0045 - val_mae: 0.0382
# Epoch 63/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112 - mae: 0.0760
# Epoch 63: val_loss improved from 0.00452 to 0.00440, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0772 - val_loss: 0.0044 - val_mae: 0.0368
# Epoch 64/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0115 - mae: 0.0764
# Epoch 64: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0119 - mae: 0.0773 - val_loss: 0.0047 - val_mae: 0.0382
# Epoch 65/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mae: 0.0780
# Epoch 65: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0118 - mae: 0.0772 - val_loss: 0.0049 - val_mae: 0.0402
# Epoch 66/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mae: 0.0762
# Epoch 66: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0114 - mae: 0.0759 - val_loss: 0.0051 - val_mae: 0.0418
# Epoch 67/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0115 - mae: 0.0768
# Epoch 67: val_loss improved from 0.00440 to 0.00440, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0116 - mae: 0.0763 - val_loss: 0.0044 - val_mae: 0.0362
# Epoch 68/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - mae: 0.0761
# Epoch 68: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0114 - mae: 0.0751 - val_loss: 0.0044 - val_mae: 0.0369
# Epoch 69/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mae: 0.0763
# Epoch 69: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0770 - val_loss: 0.0059 - val_mae: 0.0484
# Epoch 70/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mae: 0.0782
# Epoch 70: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0120 - mae: 0.0771 - val_loss: 0.0052 - val_mae: 0.0424
# Epoch 71/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mae: 0.0768
# Epoch 71: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - mae: 0.0768 - val_loss: 0.0047 - val_mae: 0.0395
# Epoch 72/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111 - mae: 0.0749
# Epoch 72: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0114 - mae: 0.0757 - val_loss: 0.0053 - val_mae: 0.0430
# Epoch 73/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - mae: 0.0776
# Epoch 73: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0116 - mae: 0.0761 - val_loss: 0.0049 - val_mae: 0.0405
# Epoch 74/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mae: 0.0763
# Epoch 74: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0115 - mae: 0.0759 - val_loss: 0.0054 - val_mae: 0.0455
# Epoch 75/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mae: 0.0757
# Epoch 75: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0117 - mae: 0.0768 - val_loss: 0.0049 - val_mae: 0.0411
# Epoch 76/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0110 - mae: 0.0745
# Epoch 76: val_loss did not improve from 0.00440
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0112 - mae: 0.0746 - val_loss: 0.0044 - val_mae: 0.0358
# Epoch 77/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0110 - mae: 0.0754
# Epoch 77: val_loss improved from 0.00440 to 0.00434, saving model to ../../Models/best_cnn_gru.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0115 - mae: 0.0759 - val_loss: 0.0043 - val_mae: 0.0359
# Epoch 78/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109 - mae: 0.0748
# Epoch 78: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0113 - mae: 0.0757 - val_loss: 0.0045 - val_mae: 0.0385
# Epoch 79/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mae: 0.0760
# Epoch 79: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0117 - mae: 0.0761 - val_loss: 0.0052 - val_mae: 0.0435
# Epoch 80/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mae: 0.0770
# Epoch 80: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0116 - mae: 0.0761 - val_loss: 0.0044 - val_mae: 0.0370
# Epoch 81/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0122 - mae: 0.0755
# Epoch 81: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0109 - mae: 0.0743 - val_loss: 0.0051 - val_mae: 0.0417
# Epoch 82/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0115 - mae: 0.0753
# Epoch 82: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0114 - mae: 0.0754 - val_loss: 0.0054 - val_mae: 0.0443
# Epoch 83/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mae: 0.0759
# Epoch 83: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0114 - mae: 0.0756 - val_loss: 0.0048 - val_mae: 0.0393
# Epoch 84/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111 - mae: 0.0751
# Epoch 84: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0114 - mae: 0.0750 - val_loss: 0.0044 - val_mae: 0.0362
# Epoch 85/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mae: 0.0759
# Epoch 85: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0116 - mae: 0.0763 - val_loss: 0.0046 - val_mae: 0.0370
# Epoch 86/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mae: 0.0755
# Epoch 86: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0115 - mae: 0.0756 - val_loss: 0.0046 - val_mae: 0.0380
# Epoch 87/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0115 - mae: 0.0761
# Epoch 87: val_loss did not improve from 0.00434
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0116 - mae: 0.0760 - val_loss: 0.0051 - val_mae: 0.0429

# %%
X_ic_test = data['X_ic_test']
X_context_test = data['X_context_test']
y_test = data['y_test']

y_mean = data['y_mean']
y_std = data['y_std']

print("Test data shape:")
print("X_ic_test shape:", X_ic_test.shape)
print("X_context_test shape:", X_context_test.shape)
print("Y_test shape:", y_test.shape)
# Out:
# Test data shape:
# X_ic_test shape: (4528, 20, 1)
# X_context_test shape: (4528, 7)
# Y_test shape: (4528,)

# %%
import joblib
joblib.dump(preprocessor, "../../preprocessing/data_preprocessor_nca.pkl")
# Out:
# ['../../preprocessing/data_preprocessor_nca.pkl']

# %%
test_loss, test_mae = model.evaluate([X_ic_test, X_context_test], y_test, verbose=1)

print(f"Test MAE (normalized): {test_mae:.4f}")
print(f"Test MSE (normalized): {test_loss:.4f}")

# Inverse transform MAE to original units
test_mae_real = test_mae * y_std
print(f"Test MAE (original SOH units): {test_mae_real:.4f}")

# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('CNN+GRU (NT) Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('CNN+GRU (NT) MAE over Epochs')

plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0350
# Test MAE (normalized): 0.0350
# Test MSE (normalized): 0.0026
# Test MAE (original SOH units): 0.2326

# %%
y_pred = model.predict([X_ic_test, X_context_test]).flatten()

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+GRU (NT) SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
r2 = r2_score(y_test, y_pred)

print(f"R-squared (normalized): {r2:.4f}")

y_test_real = y_test * y_std + y_mean
y_pred_real = y_pred * y_std + y_mean

r2_real = r2_score(y_test_real, y_pred_real)
print(f"R-squared (original SOH units): {r2_real:.4f}")
# Out:
# R-squared (normalized): 0.9974
# R-squared (original SOH units): 0.9974

# %%
X_ic_test_25 = []
X_context_test_25 = []
X_ic_test_35 = []
X_context_test_35 = []
X_ic_test_45 = []
X_context_test_45 = []
y_test_25 = []
y_test_35 = []  
y_test_45 = []

for i in range(X_context_test.shape[0]):
    if X_context_test[i, 1] > 0:      # temp_25 one-hot
        X_ic_test_25.append(X_ic_test[i])
        X_context_test_25.append(X_context_test[i])
        y_test_25.append(y_test[i])
    if X_context_test[i, 2] > 0:      # temp_35 one-hot
        X_ic_test_35.append(X_ic_test[i])
        X_context_test_35.append(X_context_test[i])
        y_test_35.append(y_test[i])
    if X_context_test[i, 3] > 0:      # temp_45 one-hot
        X_ic_test_45.append(X_ic_test[i])
        X_context_test_45.append(X_context_test[i])
        y_test_45.append(y_test[i])

X_ic_test_25 = np.array(X_ic_test_25)
X_ic_test_35 = np.array(X_ic_test_35)
X_ic_test_45 = np.array(X_ic_test_45)

X_context_test_25 = np.array(X_context_test_25)
X_context_test_35 = np.array(X_context_test_35)
X_context_test_45 = np.array(X_context_test_45)

y_test_25 = np.array(y_test_25)
y_test_35 = np.array(y_test_35)
y_test_45 = np.array(y_test_45)

print(X_ic_test_25.shape)
print(X_ic_test_35.shape)
print(X_ic_test_45.shape)

print(X_context_test_25.shape)
print(X_context_test_35.shape)
print(X_context_test_45.shape)


print(y_test_25.shape)
print(y_test_35.shape)
print(y_test_45.shape)
# Out:
# (1162, 20, 1)
# (235, 20, 1)
# (3131, 20, 1)
# (1162, 7)
# (235, 7)
# (3131, 7)
# (1162,)
# (235,)
# (3131,)

# %%
X_ic_test_25_seq = np.expand_dims(X_ic_test_25, axis=2)
X_ic_test_35_seq = np.expand_dims(X_ic_test_35, axis=2)
X_ic_test_45_seq = np.expand_dims(X_ic_test_45, axis=2)
print(X_ic_test_25_seq.shape)
print(X_ic_test_35_seq.shape)
print(X_ic_test_45_seq.shape)
# Out:
# (1162, 20, 1, 1)
# (235, 20, 1, 1)
# (3131, 20, 1, 1)

# %%
cnn_gru = keras.models.load_model(r'../../Models/best_cnn_gru.keras')

# %%
y_pred_25_scaled = cnn_gru.predict([X_ic_test_25_seq, X_context_test_25]).flatten()
y_pred_35_scaled = cnn_gru.predict([X_ic_test_35_seq, X_context_test_35]).flatten()
y_pred_45_scaled = cnn_gru.predict([X_ic_test_45_seq, X_context_test_45]).flatten()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred_25 = y_pred_25_scaled * y_std + y_mean
y_pred_35 = y_pred_35_scaled * y_std + y_mean
y_pred_45 = y_pred_45_scaled * y_std + y_mean

y_true_25 = y_test_25 * y_std + y_mean
y_true_35 = y_test_35 * y_std + y_mean
y_true_45 = y_test_45 * y_std + y_mean

# %%
def metrics(y_t, y_p):
    return (mean_absolute_error(y_t, y_p),
            mean_squared_error(y_t, y_p),
            r2_score(y_t, y_p))

mae_25, mse_25, r2_25 = metrics(y_true_25, y_pred_25)
print("25C → MAE:", mae_25, "MSE:", mse_25, "R²:", r2_25)


mae_35, mse_35, r2_35 = metrics(y_true_35, y_pred_35)
print("35C → MAE:", mae_35, "MSE:", mse_35, "R²:", r2_35)

mae_45, mse_45, r2_45 = metrics(y_true_45, y_pred_45)
print("45C → MAE:", mae_45, "MSE:", mse_45, "R²:", r2_45)
# Out:
# 25C → MAE: 0.3450677340087866 MSE: 0.2109656917785824 R²: 0.9940113606042108
# 35C → MAE: 0.12652885920755164 MSE: 0.03894624393680579 R²: 0.9987791843206574
# 45C → MAE: 0.19888753242238713 MSE: 0.08364736775660409 R²: 0.9978735434825501

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scatter(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=0.6, s=15)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    plt.title(title, fontsize=14)
    plt.xlabel("True SOH", fontsize=12)
    plt.ylabel("Predicted SOH", fontsize=12)
    plt.grid(True)

# %%
plt.figure(figsize=(22,6))

plt.subplot(1,3,1)
plot_scatter(y_true_25, y_pred_25, "CNN+GRU (NT) SOH Prediction @ 25°C")

plt.subplot(1,3,2)
plot_scatter(y_true_35, y_pred_35, "CNN+GRU (NT) SOH Prediction @ 35°C")

plt.subplot(1,3,3)
plot_scatter(y_true_45, y_pred_45, "CNN+GRU (NT) SOH Prediction @ 45°C")

plt.show()
