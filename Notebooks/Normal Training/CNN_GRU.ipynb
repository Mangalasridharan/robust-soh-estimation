# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Dropout, Input, Concatenate # type: ignore
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # type: ignore
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../Dataset/NCA Preprocessed/master_features_nca.csv')
df
# Out:
#                 filename  cell_id  temp  charge_rate  discharge_rate  cycle  \
# 0      CY25-025_1-#1.csv        1    25         0.25             1.0      1
# 1      CY25-025_1-#1.csv        1    25         0.25             1.0      2
# 2      CY25-025_1-#1.csv        1    25         0.25             1.0      3
# 3      CY25-025_1-#1.csv        1    25         0.25             1.0      4
# 4      CY25-025_1-#1.csv        1    25         0.25             1.0      5
# ...                  ...      ...   ...          ...             ...    ...
# 22639   CY45-05_1-#9.csv        9    45         0.50             1.0    411
# 22640   CY45-05_1-#9.csv        9    45         0.50             1.0    412
# 22641   CY45-05_1-#9.csv        9    45         0.50             1.0    413
# 22642   CY45-05_1-#9.csv        9    45         0.50             1.0    414
# 22643   CY45-05_1-#9.csv        9    45         0.50             1.0    415
#
#           SOH  IC_bin_1  IC_bin_2  IC_bin_3  ...  IC_bin_11  IC_bin_12  \
# 0       99.96  3.206253  3.435524  3.772510  ...   4.255246   4.207070
# 1       99.98  3.185611  3.409977  3.737496  ...   4.249921   4.223132
# 2      100.00  3.166235  3.397673  3.713245  ...   4.235653   4.189766
# 3       99.97  3.139468  3.376350  3.683448  ...   4.254307   4.162355
# 4       99.93  3.132129  3.346752  3.653736  ...   4.216513   4.164974
# ...       ...       ...       ...       ...  ...        ...        ...
# 22639   84.65  2.514883  2.565545  2.627766  ...   3.248165   3.376864
# 22640   84.61  2.510205  2.560754  2.625429  ...   3.250500   3.392370
# 22641   84.60  2.513525  2.562124  2.623266  ...   3.245492   3.372555
# 22642   84.58  2.508238  2.557557  2.619624  ...   3.241048   3.372799
# 22643   84.55  2.509477  2.557809  2.618544  ...   3.239394   3.363069
#
#        IC_bin_13  IC_bin_14  IC_bin_15  IC_bin_16  IC_bin_17  IC_bin_18  \
# 0       4.229390   4.248806   4.264151   4.198406   4.058616   3.920543
# 1       4.181276   4.225006   4.231327   4.158785   4.055173   3.905594
# 2       4.140167   4.167926   4.180849   4.145106   4.015124   3.896722
# 3       4.134256   4.143371   4.135573   4.118733   4.023064   3.867330
# 4       4.094929   4.101335   4.135343   4.100581   4.008745   3.881142
# ...          ...        ...        ...        ...        ...        ...
# 22639   3.545380   3.705835   3.774339   3.705556   3.564230   3.413748
# 22640   3.559592   3.706725   3.763518   3.694866   3.559024   3.417873
# 22641   3.540142   3.694258   3.752898   3.692722   3.562536   3.425323
# 22642   3.540815   3.700767   3.761809   3.701606   3.569719   3.425509
# 22643   3.529577   3.692710   3.758408   3.703477   3.570270   3.425148
#
#        IC_bin_19  IC_bin_20
# 0       3.792856   3.647914
# 1       3.737473   3.648392
# 2       3.756668   3.646670
# 3       3.752034   3.631178
# 4       3.761407   3.626212
# ...          ...        ...
# 22639   3.287599   3.193869
# 22640   3.299083   3.207045
# 22641   3.303745   3.206924
# 22642   3.299934   3.202914
# 22643   3.298753   3.200880
#
# [22644 rows x 27 columns]

# %%
import sys
sys.path.append("../../")
from preprocessing.data_preprocessor import DataPreprocessor


preprocessor = DataPreprocessor(
    train_size=0.8,
    ic_low=0,
    ic_high=20
)

data = preprocessor.preprocess(df)

X_ic_train = data["X_ic_train"]
X_context_train = data["X_context_train"]
y_train = data["y_train"]


print("Train Data shape:")
print("X_ic_train shape:", X_ic_train.shape)
print("X_context_train shape:", X_context_train.shape)
print("y_train shape:",y_train.shape)
# Out:
# Train Data shape:
# X_ic_train shape: (18109, 20, 1)
# X_context_train shape: (18109, 7)
# y_train shape: (18109,)

# %%
ic_input = Input(shape=(X_ic_train.shape[1],X_ic_train.shape[2]), name='ic_input')

x = Conv1D(filters=64, kernel_size=3, activation='relu')(ic_input)
x = MaxPooling1D(pool_size=2)(x)

x = Conv1D(filters=128, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

x = GRU(units=50, return_sequences=False)(x)

context_input = Input(shape=(X_context_train.shape[1],), name='context_input')

c = Dense(32, activation='relu')(context_input)

combined = Concatenate()([x,c])

z = Dense(64, activation='relu')(combined)
z = Dropout(0.2)(z)
output = Dense(1, activation='linear')(z)

model = Model(inputs=[ic_input, context_input], outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ic_input            │ (None, 20, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 18, 64)    │        256 │ ic_input[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 9, 64)     │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 7, 128)    │     24,704 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 3, 128)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context_input       │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 50)        │     27,000 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        256 │ context_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 82)        │          0 │ gru[0][0],        │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      5,312 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 57,593 (224.97 KB)
#  Trainable params: 57,593 (224.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('../../Models/CNN_GRU_NT.keras', monitor='val_loss',
                              save_best_only=True, verbose=1)

history = model.fit(
    [X_ic_train, X_context_train], y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3345 - mae: 0.4053
# Epoch 1: val_loss improved from None to 0.03746, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.1564 - mae: 0.2628 - val_loss: 0.0375 - val_mae: 0.1206
# Epoch 2/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0499 - mae: 0.1578
# Epoch 2: val_loss improved from 0.03746 to 0.01981, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0456 - mae: 0.1512 - val_loss: 0.0198 - val_mae: 0.0912
# Epoch 3/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0334 - mae: 0.1312
# Epoch 3: val_loss improved from 0.01981 to 0.01207, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0299 - mae: 0.1252 - val_loss: 0.0121 - val_mae: 0.0710
# Epoch 4/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260 - mae: 0.1174
# Epoch 4: val_loss improved from 0.01207 to 0.01007, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0247 - mae: 0.1146 - val_loss: 0.0101 - val_mae: 0.0668
# Epoch 5/100
# 440/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0214 - mae: 0.1061
# Epoch 5: val_loss improved from 0.01007 to 0.01004, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0205 - mae: 0.1040 - val_loss: 0.0100 - val_mae: 0.0662
# Epoch 6/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0208 - mae: 0.1044
# Epoch 6: val_loss improved from 0.01004 to 0.00832, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0197 - mae: 0.1017 - val_loss: 0.0083 - val_mae: 0.0593
# Epoch 7/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - mae: 0.0981
# Epoch 7: val_loss did not improve from 0.00832
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0185 - mae: 0.0983 - val_loss: 0.0089 - val_mae: 0.0616
# Epoch 8/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - mae: 0.0961
# Epoch 8: val_loss improved from 0.00832 to 0.00758, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0178 - mae: 0.0963 - val_loss: 0.0076 - val_mae: 0.0557
# Epoch 9/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176 - mae: 0.0953
# Epoch 9: val_loss did not improve from 0.00758
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0172 - mae: 0.0937 - val_loss: 0.0078 - val_mae: 0.0552
# Epoch 10/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0157 - mae: 0.0905
# Epoch 10: val_loss improved from 0.00758 to 0.00731, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0164 - mae: 0.0920 - val_loss: 0.0073 - val_mae: 0.0536
# Epoch 11/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0166 - mae: 0.0929
# Epoch 11: val_loss improved from 0.00731 to 0.00663, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0161 - mae: 0.0911 - val_loss: 0.0066 - val_mae: 0.0489
# Epoch 12/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158 - mae: 0.0908
# Epoch 12: val_loss did not improve from 0.00663
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0160 - mae: 0.0903 - val_loss: 0.0071 - val_mae: 0.0528
# Epoch 13/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - mae: 0.0895
# Epoch 13: val_loss did not improve from 0.00663
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0153 - mae: 0.0885 - val_loss: 0.0070 - val_mae: 0.0498
# Epoch 14/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - mae: 0.0908
# Epoch 14: val_loss improved from 0.00663 to 0.00636, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0157 - mae: 0.0892 - val_loss: 0.0064 - val_mae: 0.0476
# Epoch 15/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - mae: 0.0893
# Epoch 15: val_loss did not improve from 0.00636
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0155 - mae: 0.0887 - val_loss: 0.0066 - val_mae: 0.0490
# Epoch 16/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - mae: 0.0872
# Epoch 16: val_loss improved from 0.00636 to 0.00633, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0151 - mae: 0.0880 - val_loss: 0.0063 - val_mae: 0.0485
# Epoch 17/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - mae: 0.0871
# Epoch 17: val_loss did not improve from 0.00633
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0148 - mae: 0.0869 - val_loss: 0.0067 - val_mae: 0.0499
# Epoch 18/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - mae: 0.0873
# Epoch 18: val_loss improved from 0.00633 to 0.00579, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0147 - mae: 0.0864 - val_loss: 0.0058 - val_mae: 0.0443
# Epoch 19/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mae: 0.0867
# Epoch 19: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0148 - mae: 0.0863 - val_loss: 0.0060 - val_mae: 0.0450
# Epoch 20/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0837
# Epoch 20: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0144 - mae: 0.0850 - val_loss: 0.0068 - val_mae: 0.0503
# Epoch 21/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0835
# Epoch 21: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0140 - mae: 0.0847 - val_loss: 0.0062 - val_mae: 0.0469
# Epoch 22/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0841
# Epoch 22: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0138 - mae: 0.0838 - val_loss: 0.0079 - val_mae: 0.0569
# Epoch 23/100
# 445/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0851
# Epoch 23: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.0846 - val_loss: 0.0061 - val_mae: 0.0450
# Epoch 24/100
# 439/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mae: 0.0855
# Epoch 24: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.0847 - val_loss: 0.0059 - val_mae: 0.0460
# Epoch 25/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - mae: 0.0838
# Epoch 25: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.0838 - val_loss: 0.0070 - val_mae: 0.0516
# Epoch 26/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0843
# Epoch 26: val_loss did not improve from 0.00579
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.0845 - val_loss: 0.0064 - val_mae: 0.0477
# Epoch 27/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mae: 0.0834
# Epoch 27: val_loss improved from 0.00579 to 0.00573, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0137 - mae: 0.0833 - val_loss: 0.0057 - val_mae: 0.0451
# Epoch 28/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0836
# Epoch 28: val_loss did not improve from 0.00573
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.0835 - val_loss: 0.0061 - val_mae: 0.0480
# Epoch 29/100
# 441/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - mae: 0.0847
# Epoch 29: val_loss improved from 0.00573 to 0.00557, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0142 - mae: 0.0846 - val_loss: 0.0056 - val_mae: 0.0424
# Epoch 30/100
# 444/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0822
# Epoch 30: val_loss did not improve from 0.00557
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0135 - mae: 0.0827 - val_loss: 0.0058 - val_mae: 0.0460
# Epoch 31/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - mae: 0.0839
# Epoch 31: val_loss did not improve from 0.00557
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0137 - mae: 0.0833 - val_loss: 0.0056 - val_mae: 0.0441
# Epoch 32/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0817
# Epoch 32: val_loss improved from 0.00557 to 0.00555, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0137 - mae: 0.0830 - val_loss: 0.0055 - val_mae: 0.0434
# Epoch 33/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140 - mae: 0.0836
# Epoch 33: val_loss did not improve from 0.00555
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0138 - mae: 0.0831 - val_loss: 0.0057 - val_mae: 0.0449
# Epoch 34/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - mae: 0.0851
# Epoch 34: val_loss improved from 0.00555 to 0.00532, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0141 - mae: 0.0846 - val_loss: 0.0053 - val_mae: 0.0418
# Epoch 35/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0828
# Epoch 35: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0136 - mae: 0.0828 - val_loss: 0.0058 - val_mae: 0.0458
# Epoch 36/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145 - mae: 0.0835
# Epoch 36: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0136 - mae: 0.0824 - val_loss: 0.0064 - val_mae: 0.0482
# Epoch 37/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0816
# Epoch 37: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0133 - mae: 0.0822 - val_loss: 0.0057 - val_mae: 0.0459
# Epoch 38/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0812
# Epoch 38: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0133 - mae: 0.0815 - val_loss: 0.0053 - val_mae: 0.0423
# Epoch 39/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - mae: 0.0828
# Epoch 39: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0132 - mae: 0.0813 - val_loss: 0.0068 - val_mae: 0.0539
# Epoch 40/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0837
# Epoch 40: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0134 - mae: 0.0820 - val_loss: 0.0055 - val_mae: 0.0436
# Epoch 41/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0818
# Epoch 41: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0135 - mae: 0.0824 - val_loss: 0.0057 - val_mae: 0.0437
# Epoch 42/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - mae: 0.0818
# Epoch 42: val_loss did not improve from 0.00532
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0132 - mae: 0.0810 - val_loss: 0.0054 - val_mae: 0.0427
# Epoch 43/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mae: 0.0801
# Epoch 43: val_loss improved from 0.00532 to 0.00511, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0131 - mae: 0.0810 - val_loss: 0.0051 - val_mae: 0.0412
# Epoch 44/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0812
# Epoch 44: val_loss did not improve from 0.00511
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0131 - mae: 0.0812 - val_loss: 0.0054 - val_mae: 0.0425
# Epoch 45/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mae: 0.0824
# Epoch 45: val_loss did not improve from 0.00511
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0134 - mae: 0.0819 - val_loss: 0.0054 - val_mae: 0.0424
# Epoch 46/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - mae: 0.0808
# Epoch 46: val_loss improved from 0.00511 to 0.00507, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0133 - mae: 0.0818 - val_loss: 0.0051 - val_mae: 0.0404
# Epoch 47/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - mae: 0.0825
# Epoch 47: val_loss did not improve from 0.00507
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0131 - mae: 0.0811 - val_loss: 0.0061 - val_mae: 0.0482
# Epoch 48/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mae: 0.0806
# Epoch 48: val_loss did not improve from 0.00507
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0128 - mae: 0.0804 - val_loss: 0.0051 - val_mae: 0.0404
# Epoch 49/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.0807
# Epoch 49: val_loss improved from 0.00507 to 0.00501, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0131 - mae: 0.0815 - val_loss: 0.0050 - val_mae: 0.0394
# Epoch 50/100
# 442/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mae: 0.0819
# Epoch 50: val_loss did not improve from 0.00501
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0134 - mae: 0.0817 - val_loss: 0.0054 - val_mae: 0.0426
# Epoch 51/100
# 447/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mae: 0.0815
# Epoch 51: val_loss improved from 0.00501 to 0.00475, saving model to ../../Models/CNN_GRU_NT.keras
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0133 - mae: 0.0812 - val_loss: 0.0047 - val_mae: 0.0383
# Epoch 52/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mae: 0.0798
# Epoch 52: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0128 - mae: 0.0801 - val_loss: 0.0050 - val_mae: 0.0400
# Epoch 53/100
# 449/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mae: 0.0811
# Epoch 53: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0131 - mae: 0.0805 - val_loss: 0.0049 - val_mae: 0.0386
# Epoch 54/100
# 446/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mae: 0.0790
# Epoch 54: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0129 - mae: 0.0800 - val_loss: 0.0053 - val_mae: 0.0428
# Epoch 55/100
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0809
# Epoch 55: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0127 - mae: 0.0804 - val_loss: 0.0053 - val_mae: 0.0416
# Epoch 56/100
# 448/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mae: 0.0813
# Epoch 56: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0131 - mae: 0.0807 - val_loss: 0.0052 - val_mae: 0.0418
# Epoch 57/100
# 451/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mae: 0.0802
# Epoch 57: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0129 - mae: 0.0799 - val_loss: 0.0057 - val_mae: 0.0458
# Epoch 58/100
# 443/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mae: 0.0794
# Epoch 58: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0126 - mae: 0.0798 - val_loss: 0.0058 - val_mae: 0.0457
# Epoch 59/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - mae: 0.0796
# Epoch 59: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0123 - mae: 0.0785 - val_loss: 0.0058 - val_mae: 0.0462
# Epoch 60/100
# 452/453 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mae: 0.0791
# Epoch 60: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0126 - mae: 0.0798 - val_loss: 0.0055 - val_mae: 0.0446
# Epoch 61/100
# 450/453 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - mae: 0.0802
# Epoch 61: val_loss did not improve from 0.00475
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0124 - mae: 0.0790 - val_loss: 0.0056 - val_mae: 0.0452

# %%
X_ic_test = data['X_ic_test']
X_context_test = data['X_context_test']
y_test_norm = data['y_test']

y_mean = data['y_mean']
y_std = data['y_std']

print("Test data shape:")
print("X_ic_test shape:", X_ic_test.shape)
print("X_context_test shape:", X_context_test.shape)
print("Y_test shape:", y_test_norm.shape)
# Out:
# Test data shape:
# X_ic_test shape: (4528, 20, 1)
# X_context_test shape: (4528, 7)
# Y_test shape: (4528,)

# %%
# ======================================
# 6. Plot training history
# ======================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('MAE over Epochs')

plt.show()

# %%
import matplotlib.pyplot as plt

y_pred_norm = model.predict([X_ic_test, X_context_test]).flatten()

y_pred = y_pred_norm * y_std + y_mean
y_test = y_test_norm * y_std + y_mean

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("True SOH")
plt.ylabel("Predicted SOH")
plt.title("CNN+GRU NT SOH Prediction")
plt.show()
# Out:
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
cnn_gru = keras.models.load_model(r'../../Models/CNN_GRU_NT.keras')

# %%
from utils.data_split import temp_based_split

data = temp_based_split(X_ic_test, X_context_test, y_test_norm)
# Out:
# -----25 degree Celsius-----
# X_ic shape: (1162, 20, 1)
# X_context shape: (1162, 7)
# y_test shape: (1162,)
#
# -----35 degree Celsius-----
# X_ic shape: (235, 20, 1)
# X_context shape: (235, 7)
# y_test shape: (235,)
#
# -----45 degree Celsius-----
# X_ic shape: (3131, 20, 1)
# X_context shape: (3131, 7)
# y_test shape: (3131,)

# %%
from utils.predict import make_predictions

predicitons, true, metrics = make_predictions(cnn_gru, data, y_mean, y_std)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from utils.plots import scatter_plot

scatter_plot(predicitons, true, y_std, y_mean, model_name="CNN+GRU NT")

# %%
from utils.metrics import get_metrics, format_metrics

metrics = get_metrics(predicitons, true, y_mean, y_std)

format_metrics(metrics, model_name="CNN+GRU NT")
# Out:
# ============================================================
# CNN+GRU NT Metrics - NORMALIZED
# ============================================================
#
# +---------------+----------+----------+------------+
# | Temperature   |      MAE |      MSE |   R2 Score |
# +===============+==========+==========+============+
# | 25            | 0.056726 | 0.005676 |   0.992879 |
# +---------------+----------+----------+------------+
# | 35            | 0.028247 | 0.001422 |   0.99803  |
# +---------------+----------+----------+------------+
# | 45            | 0.031208 | 0.002065 |   0.99768  |
# +---------------+----------+----------+------------+
# | complete      | 0.037603 | 0.002958 |   0.99705  |
# +---------------+----------+----------+------------+
#
#
# ============================================================
# CNN+GRU NT Metrics - ORIGINAL
# ============================================================
#
# +---------------+----------+----------+------------+
# | Temperature   |      MAE |      MSE |   R2 Score |
# +===============+==========+==========+============+
# | 25            | 0.377106 | 0.250863 |   0.992879 |
# +---------------+----------+----------+------------+
# | 35            | 0.187781 | 0.062856 |   0.99803  |
# +---------------+----------+----------+------------+
# | 45            | 0.207469 | 0.091258 |   0.99768  |
# +---------------+----------+----------+------------+
# | complete      | 0.249981 | 0.130742 |   0.99705  |
# +---------------+----------+----------+------------+
